# %%
import pandas as pd
import numpy as np
import warnings
import sys
from datetime import timedelta
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import csv

sys.path.append("..")
# sys.path.append(".")
from tool import market_dynamics_modeling_analysis
from tool import label_util as util
from comprehensive_evaluation.analyzer import *
from comprehensive_evaluation.util import *
from comprehensive_evaluation.slice_model import *
import bisect

# %%
positions = np.load("../best_result/BTCT/micro_action.npy")
data = pd.read_feather("../best_result/BTCT/test.feather")
path = "../best_result/BTCT/data"

# positions = np.load("../best_result/BTCU/micro_action.npy")
# data = pd.read_feather("../best_result/BTCU/test.feather")
# path = "../best_result/BTCU/data"

isExist = os.path.exists(path)
if not isExist:
    os.makedirs(path)
    print("The new directory is created! {}".format(path))

max_holding_number1 = 0.01
commission_fee = 0

num_seg = 5
num_dynamics = 5
selected_timestamp = [
    pd.Timestamp(data[0:1]["timestamp"].values[0]),
    pd.Timestamp(data.iloc[-1]["timestamp"]),
]

# %%
def find_previous_element(sorted_list, value):
    index = bisect.bisect_left(sorted_list, value)
    if index == 0:
        return None  # 给定值小于列表中的所有元素
    else:
        return sorted_list[index - 1]

# %%
strategy = transform_market_order_strategy(data, positions, max_holding_number=max_holding_number1)

# %%
data
# Out:
#                  timestamp   symbol  ask1_price  ask1_size  bid1_price
# 0      2023-05-06 14:36:12  BTCTUSD    28664.95    0.00500    28663.24  \
# 1      2023-05-06 14:36:13  BTCTUSD    28664.93    0.01965    28662.65
# 2      2023-05-06 14:36:14  BTCTUSD    28664.87    0.00499    28662.66
# 3      2023-05-06 14:36:15  BTCTUSD    28664.84    0.00209    28662.66
# 4      2023-05-06 14:36:16  BTCTUSD    28664.84    0.00209    28662.66
# ...                    ...      ...         ...        ...         ...
# 811423 2023-05-15 23:59:55  BTCTUSD    27184.57    0.00262    27180.62
# 811424 2023-05-15 23:59:56  BTCTUSD    27183.00    0.00332    27182.41
# 811425 2023-05-15 23:59:57  BTCTUSD    27187.12    0.00350    27184.03
# 811426 2023-05-15 23:59:58  BTCTUSD    27184.81    0.04512    27184.80
# 811427 2023-05-15 23:59:59  BTCTUSD    27185.81    0.00200    27184.82
#
#         bid1_size  ask2_price  ask2_size  bid2_price  bid2_size  ...
# 0         0.17441    28665.00    0.00367    28662.79    0.00286  ...  \
# 1         0.01048    28664.94    0.05140    28662.60    0.00400  ...
# 2         0.00800    28664.92    0.00172    28662.60    0.06677  ...
# 3         0.00070    28664.85    0.00046    28661.70    0.06448  ...
# 4         0.00070    28664.85    0.00046    28661.73    0.10415  ...
# ...           ...         ...        ...         ...        ...  ...
# 811423    0.00337    27184.58    0.00101    27180.61    0.28700  ...
# 811424    0.01839    27184.54    0.00097    27182.40    0.00184  ...
# 811425    0.03640    27187.15    0.00097    27183.77    0.05247  ...
# 811426    0.00187    27185.61    0.00342    27184.79    0.00044  ...
# 811427    0.01780    27185.87    0.00268    27184.81    0.03055  ...
#
#         roc_60_m  beta_60_m  max_60_m  min_60_m  qtlu_60_m  qtld_60_m
# 0       1.959904   0.032665  2.449864 -0.223321   2.038318  -0.001547  \
# 1       1.959904   0.032665  2.449864 -0.223321   2.038318  -0.001547
# 2       1.959904   0.032665  2.449864 -0.223321   2.038318  -0.001547
# 3       1.959904   0.032665  2.449864 -0.223321   2.038318  -0.001547
# 4       1.959904   0.032665  2.449864 -0.223321   2.038318  -0.001547
# ...          ...        ...       ...       ...        ...        ...
# 811423  2.517071   0.041951  2.521515 -0.513515   2.235910   0.138297
# 811424  2.517071   0.041951  2.521515 -0.513515   2.235910   0.138297
# 811425  2.517071   0.041951  2.521515 -0.513515   2.235910   0.138297
# 811426  2.517071   0.041951  2.521515 -0.513515   2.235910   0.138297
# 811427  2.517071   0.041951  2.521515 -0.513515   2.235910   0.138297
#
#         imax_60_m  imin_60_m  imxd_60_m  imxd_60_dis_m
# 0        0.200000   0.516667  -0.316667            0.0
# 1        0.200000   0.516667  -0.316667            0.0
# 2        0.200000   0.516667  -0.316667            0.0
# 3        0.200000   0.516667  -0.316667            0.0
# 4        0.200000   0.516667  -0.316667            0.0
# ...           ...        ...        ...            ...
# 811423   0.183333   0.766667  -0.583333            0.0
# 811424   0.183333   0.766667  -0.583333            0.0
# 811425   0.183333   0.766667  -0.583333            0.0
# 811426   0.183333   0.766667  -0.583333            0.0
# 811427   0.183333   0.766667  -0.583333            0.0
#
# [811428 rows x 258 columns]

# %%
strategy
# Out:
# [{'timestamp': Timestamp('2023-05-06 14:48:21'),
#   'action': 'buy',
#   'order': [{'price': 28667.82, 'amount': 0.0021},
#    {'price': 28668.23, 'amount': 0.00209},
#    {'price': 28668.59, 'amount': 0.002},
#    {'price': 28668.71, 'amount': 0.003810000000000001}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-06 15:35:37'),
#   'action': 'sell',
#   'order': [{'price': 28596.89, 'amount': 0.01}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-06 15:39:00'),
#   'action': 'buy',
#   'order': [{'price': 28631.9, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-06 17:27:07'),
#   'action': 'sell',
#   'order': [{'price': 28816.49, 'amount': 0.0025}],
#   'position': 0.0075},
#  {'timestamp': Timestamp('2023-05-06 17:27:11'),
#   'action': 'buy',
#   'order': [{'price': 28814.55, 'amount': 0.0025}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-06 18:18:11'),
#   'action': 'sell',
#   'order': [{'price': 28954.01, 'amount': 0.01}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-06 18:18:33'),
#   'action': 'buy',
#   'order': [{'price': 28929.0, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-06 18:44:25'),
#   'action': 'sell',
#   'order': [{'price': 28965.38, 'amount': 0.0025}],
#   'position': 0.0075},
#  {'timestamp': Timestamp('2023-05-06 18:44:26'),
#   'action': 'sell',
#   'order': [{'price': 28962.9, 'amount': 0.0075}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-06 18:49:28'),
#   'action': 'buy',
#   'order': [{'price': 28972.05, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-06 21:58:30'),
#   'action': 'sell',
#   'order': [{'price': 28854.9, 'amount': 0.0075}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-06 21:58:45'),
#   'action': 'sell',
#   'order': [{'price': 28848.18, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-06 23:08:15'),
#   'action': 'buy',
#   'order': [{'price': 28907.18, 'amount': 0.00038},
#    {'price': 28907.92, 'amount': 0.00962}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-07 00:54:06'),
#   'action': 'sell',
#   'order': [{'price': 28970.21, 'amount': 0.0075}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-07 00:54:10'),
#   'action': 'sell',
#   'order': [{'price': 28976.65, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-07 01:19:10'),
#   'action': 'buy',
#   'order': [{'price': 28971.47, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-07 01:27:37'),
#   'action': 'sell',
#   'order': [{'price': 29138.08, 'amount': 0.0075}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-07 01:27:39'),
#   'action': 'sell',
#   'order': [{'price': 29127.63, 'amount': 0.00045},
#    {'price': 29127.62, 'amount': 0.00205}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-07 01:28:26'),
#   'action': 'buy',
#   'order': [{'price': 29136.36, 'amount': 0.00403},
#    {'price': 29136.37, 'amount': 0.0059700000000000005}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-07 05:32:26'),
#   'action': 'sell',
#   'order': [{'price': 28906.81, 'amount': 0.00068},
#    {'price': 28906.8, 'amount': 0.00682}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-07 05:33:08'),
#   'action': 'sell',
#   'order': [{'price': 28913.43, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-07 11:38:08'),
#   'action': 'buy',
#   'order': [{'price': 28950.99, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-07 14:34:30'),
#   'action': 'sell',
#   'order': [{'price': 29045.07, 'amount': 0.01}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-07 14:34:31'),
#   'action': 'buy',
#   'order': [{'price': 29040.75, 'amount': 0.00434},
#    {'price': 29049.15, 'amount': 0.00066}],
#   'position': 0.005},
#  {'timestamp': Timestamp('2023-05-07 14:34:32'),
#   'action': 'sell',
#   'order': [{'price': 29033.77, 'amount': 0.005}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-07 14:35:04'),
#   'action': 'buy',
#   'order': [{'price': 29057.14, 'amount': 0.0075}],
#   'position': 0.0075},
#  {'timestamp': Timestamp('2023-05-07 14:35:08'),
#   'action': 'buy',
#   'order': [{'price': 29049.11, 'amount': 0.0025}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-07 14:49:19'),
#   'action': 'sell',
#   'order': [{'price': 29053.69, 'amount': 0.002},
#    {'price': 29050.98, 'amount': 0.00164},
#    {'price': 29050.64, 'amount': 0.0038599999999999997}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-07 14:49:24'),
#   'action': 'sell',
#   'order': [{'price': 29053.88, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-07 14:50:20'),
#   'action': 'buy',
#   'order': [{'price': 29090.45, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-07 15:09:42'),
#   'action': 'sell',
#   'order': [{'price': 29051.9, 'amount': 0.00035},
#    {'price': 29046.71, 'amount': 0.00965}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-07 15:51:11'),
#   'action': 'buy',
#   'order': [{'price': 29009.61, 'amount': 3e-05},
#    {'price': 29009.68, 'amount': 0.00111},
#    {'price': 29009.95, 'amount': 0.002},
#    {'price': 29009.96, 'amount': 0.00686}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-07 19:57:24'),
#   'action': 'sell',
#   'order': [{'price': 28948.0, 'amount': 0.00306},
#    {'price': 28947.94, 'amount': 0.00068},
#    {'price': 28947.89, 'amount': 0.0012600000000000003}],
#   'position': 0.005},
#  {'timestamp': Timestamp('2023-05-07 19:59:05'),
#   'action': 'buy',
#   'order': [{'price': 28957.02, 'amount': 0.0025}],
#   'position': 0.0075},
#  {'timestamp': Timestamp('2023-05-07 19:59:48'),
#   'action': 'buy',
#   'order': [{'price': 28950.99, 'amount': 0.0025}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-07 20:10:39'),
#   'action': 'sell',
#   'order': [{'price': 28974.73, 'amount': 0.0075}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-07 20:11:01'),
#   'action': 'sell',
#   'order': [{'price': 28970.93, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-08 00:12:12'),
#   'action': 'buy',
#   'order': [{'price': 28582.33, 'amount': 0.00155},
#    {'price': 28583.14, 'amount': 0.008450000000000001}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-08 00:42:10'),
#   'action': 'sell',
#   'order': [{'price': 28643.31, 'amount': 0.00059},
#    {'price': 28641.65, 'amount': 0.00191}],
#   'position': 0.0075},
#  {'timestamp': Timestamp('2023-05-08 00:42:12'),
#   'action': 'buy',
#   'order': [{'price': 28633.61, 'amount': 0.0025}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-08 00:42:15'),
#   'action': 'sell',
#   'order': [{'price': 28623.44, 'amount': 0.00105},
#    {'price': 28623.1, 'amount': 0.00038},
#    {'price': 28622.66, 'amount': 0.00857}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-08 01:31:04'),
#   'action': 'buy',
#   'order': [{'price': 28550.0, 'amount': 0.0025}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-08 01:31:05'),
#   'action': 'sell',
#   'order': [{'price': 28549.06, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-08 01:41:33'),
#   'action': 'buy',
#   'order': [{'price': 28553.44, 'amount': 0.005}],
#   'position': 0.005},
#  {'timestamp': Timestamp('2023-05-08 01:41:34'),
#   'action': 'buy',
#   'order': [{'price': 28553.41, 'amount': 0.0025}],
#   'position': 0.0075},
#  {'timestamp': Timestamp('2023-05-08 01:41:35'),
#   'action': 'buy',
#   'order': [{'price': 28551.41, 'amount': 0.0025}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-08 01:43:22'),
#   'action': 'sell',
#   'order': [{'price': 28429.81, 'amount': 0.01}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-08 01:43:28'),
#   'action': 'buy',
#   'order': [{'price': 28384.83, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-08 01:43:45'),
#   'action': 'sell',
#   'order': [{'price': 28311.23, 'amount': 0.01}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-08 01:43:55'),
#   'action': 'buy',
#   'order': [{'price': 28297.01, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-08 01:44:29'),
#   'action': 'sell',
#   'order': [{'price': 28222.68, 'amount': 0.00499},
#    {'price': 28222.18, 'amount': 0.00099},
#    {'price': 28218.84, 'amount': 0.002},
#    {'price': 28218.8, 'amount': 0.002020000000000001}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-08 01:44:32'),
#   'action': 'buy',
#   'order': [{'price': 28200.01, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-08 01:47:03'),
#   'action': 'sell',
#   'order': [{'price': 28187.0, 'amount': 0.01}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-08 01:47:08'),
#   'action': 'buy',
#   'order': [{'price': 28173.42, 'amount': 0.005},
#    {'price': 28173.46, 'amount': 0.00209},
#    {'price': 28173.47, 'amount': 0.0029100000000000003}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-08 02:16:03'),
#   'action': 'sell',
#   'order': [{'price': 28278.75, 'amount': 0.00159},
#    {'price': 28278.74, 'amount': 0.0006},
#    {'price': 28278.49, 'amount': 0.00031000000000000005}],
#   'position': 0.0075},
#  {'timestamp': Timestamp('2023-05-08 02:16:13'),
#   'action': 'sell',
#   'order': [{'price': 28266.03, 'amount': 0.005}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-08 02:16:15'),
#   'action': 'buy',
#   'order': [{'price': 28268.98, 'amount': 0.0075}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-08 02:16:41'),
#   'action': 'sell',
#   'order': [{'price': 28263.79, 'amount': 0.01}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-08 03:44:42'),
#   'action': 'buy',
#   'order': [{'price': 28140.01, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-08 03:56:17'),
#   'action': 'sell',
#   'order': [{'price': 28211.88, 'amount': 0.0075}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-08 03:56:19'),
#   'action': 'buy',
#   'order': [{'price': 28214.19, 'amount': 0.00234},
#    {'price': 28215.55, 'amount': 0.0005},
#    {'price': 28217.41, 'amount': 0.00216}],
#   'position': 0.0075},
#  {'timestamp': Timestamp('2023-05-08 03:56:27'),
#   'action': 'sell',
#   'order': [{'price': 28209.4, 'amount': 0.0025}],
#   'position': 0.005},
#  {'timestamp': Timestamp('2023-05-08 03:56:42'),
#   'action': 'buy',
#   'order': [{'price': 28221.9, 'amount': 0.0004},
#    {'price': 28224.82, 'amount': 0.0021}],
#   'position': 0.0075},
#  {'timestamp': Timestamp('2023-05-08 03:57:11'),
#   'action': 'buy',
#   'order': [{'price': 28227.0, 'amount': 0.0025}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-08 13:38:53'),
#   'action': 'sell',
#   'order': [{'price': 27940.0, 'amount': 0.01}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-08 14:49:17'),
#   'action': 'buy',
#   'order': [{'price': 27925.22, 'amount': 0.00716},
#    {'price': 27925.85, 'amount': 0.0028400000000000005}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-08 17:55:46'),
#   'action': 'sell',
#   'order': [{'price': 27820.83, 'amount': 0.01}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-08 18:00:01'),
#   'action': 'buy',
#   'order': [{'price': 27566.0, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-08 18:00:55'),
#   'action': 'sell',
#   'order': [{'price': 27535.02, 'amount': 0.01}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-08 18:00:57'),
#   'action': 'buy',
#   'order': [{'price': 27549.99, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-08 18:05:02'),
#   'action': 'sell',
#   'order': [{'price': 27454.01, 'amount': 0.01}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-08 18:19:05'),
#   'action': 'buy',
#   'order': [{'price': 27586.22, 'amount': 0.00125},
#    {'price': 27586.72, 'amount': 0.00875}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-08 18:54:05'),
#   'action': 'sell',
#   'order': [{'price': 27522.88, 'amount': 0.01}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-08 18:54:10'),
#   'action': 'buy',
#   'order': [{'price': 27529.76, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-08 20:41:09'),
#   'action': 'sell',
#   'order': [{'price': 27544.94, 'amount': 0.00157},
#    {'price': 27543.54, 'amount': 0.00548},
#    {'price': 27543.53, 'amount': 0.0004499999999999999}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-08 20:41:13'),
#   'action': 'sell',
#   'order': [{'price': 27562.34, 'amount': 0.00172},
#    {'price': 27562.28, 'amount': 0.0007800000000000001}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-08 21:24:19'),
#   'action': 'buy',
#   'order': [{'price': 27508.41, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-08 22:47:28'),
#   'action': 'sell',
#   'order': [{'price': 27654.0, 'amount': 0.00055},
#    {'price': 27653.0, 'amount': 0.00055},
#    {'price': 27651.0, 'amount': 0.0063999999999999994}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-08 22:47:50'),
#   'action': 'sell',
#   'order': [{'price': 27652.16, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-08 23:52:19'),
#   'action': 'buy',
#   'order': [{'price': 27718.51, 'amount': 0.004},
#    {'price': 27718.64, 'amount': 0.001},
#    {'price': 27719.18, 'amount': 0.005}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-09 03:00:24'),
#   'action': 'sell',
#   'order': [{'price': 27651.38, 'amount': 0.0075}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-09 03:01:01'),
#   'action': 'sell',
#   'order': [{'price': 27654.25, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-09 05:44:05'),
#   'action': 'buy',
#   'order': [{'price': 27619.96, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-09 06:47:14'),
#   'action': 'sell',
#   'order': [{'price': 27575.18, 'amount': 0.00128},
#    {'price': 27575.17, 'amount': 0.00622}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-09 06:47:37'),
#   'action': 'sell',
#   'order': [{'price': 27574.89, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-09 10:18:10'),
#   'action': 'buy',
#   'order': [{'price': 27620.57, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-09 11:45:14'),
#   'action': 'sell',
#   'order': [{'price': 27652.29, 'amount': 0.0025}],
#   'position': 0.0075},
#  {'timestamp': Timestamp('2023-05-09 11:45:16'),
#   'action': 'sell',
#   'order': [{'price': 27649.66, 'amount': 0.0075}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-09 11:52:00'),
#   'action': 'buy',
#   'order': [{'price': 27729.89, 'amount': 0.00625},
#    {'price': 27730.13, 'amount': 0.00375}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-09 12:15:02'),
#   'action': 'sell',
#   'order': [{'price': 27758.02, 'amount': 0.0075}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-09 12:15:07'),
#   'action': 'sell',
#   'order': [{'price': 27774.18, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-09 12:16:13'),
#   'action': 'buy',
#   'order': [{'price': 27813.24, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-09 13:07:41'),
#   'action': 'sell',
#   'order': [{'price': 27813.37, 'amount': 0.0075}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-09 13:07:45'),
#   'action': 'sell',
#   'order': [{'price': 27807.23, 'amount': 0.002},
#    {'price': 27806.74, 'amount': 0.0005}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-09 14:41:37'),
#   'action': 'buy',
#   'order': [{'price': 27530.63, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-09 14:48:16'),
#   'action': 'sell',
#   'order': [{'price': 27631.2, 'amount': 0.00039},
#    {'price': 27631.05, 'amount': 0.00113},
#    {'price': 27631.0, 'amount': 0.00081},
#    {'price': 27630.94, 'amount': 0.00517}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-09 14:48:33'),
#   'action': 'sell',
#   'order': [{'price': 27627.98, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-09 16:37:15'),
#   'action': 'buy',
#   'order': [{'price': 27507.45, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-09 16:38:45'),
#   'action': 'sell',
#   'order': [{'price': 27480.9, 'amount': 0.00074},
#    {'price': 27480.89, 'amount': 0.0067599999999999995}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-09 16:39:02'),
#   'action': 'sell',
#   'order': [{'price': 27486.12, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-09 16:46:38'),
#   'action': 'buy',
#   'order': [{'price': 27545.8, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-09 16:57:11'),
#   'action': 'sell',
#   'order': [{'price': 27671.25, 'amount': 0.00084},
#    {'price': 27671.24, 'amount': 0.00166}],
#   'position': 0.0075},
#  {'timestamp': Timestamp('2023-05-09 16:57:13'),
#   'action': 'sell',
#   'order': [{'price': 27674.58, 'amount': 0.0025}],
#   'position': 0.005},
#  {'timestamp': Timestamp('2023-05-09 16:57:17'),
#   'action': 'buy',
#   'order': [{'price': 27690.78, 'amount': 0.0005},
#    {'price': 27691.01, 'amount': 0.002}],
#   'position': 0.0075},
#  {'timestamp': Timestamp('2023-05-09 16:57:19'),
#   'action': 'buy',
#   'order': [{'price': 27703.99, 'amount': 0.0025}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-09 17:02:11'),
#   'action': 'sell',
#   'order': [{'price': 27701.27, 'amount': 0.01}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-09 17:02:25'),
#   'action': 'buy',
#   'order': [{'price': 27710.72, 'amount': 0.00216},
#    {'price': 27710.92, 'amount': 0.00784}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-09 23:03:10'),
#   'action': 'sell',
#   'order': [{'price': 27606.86, 'amount': 0.0025}],
#   'position': 0.0075},
#  {'timestamp': Timestamp('2023-05-09 23:03:27'),
#   'action': 'buy',
#   'order': [{'price': 27603.78, 'amount': 0.0025}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-10 00:20:15'),
#   'action': 'sell',
#   'order': [{'price': 27723.58, 'amount': 0.0025}],
#   'position': 0.0075},
#  {'timestamp': Timestamp('2023-05-10 00:20:19'),
#   'action': 'sell',
#   'order': [{'price': 27721.93, 'amount': 0.0025}],
#   'position': 0.005},
#  {'timestamp': Timestamp('2023-05-10 00:21:34'),
#   'action': 'sell',
#   'order': [{'price': 27731.85, 'amount': 0.005}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-10 08:12:24'),
#   'action': 'buy',
#   'order': [{'price': 27556.57, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-10 11:59:19'),
#   'action': 'sell',
#   'order': [{'price': 27702.69, 'amount': 0.01}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-10 12:32:11'),
#   'action': 'buy',
#   'order': [{'price': 27966.44, 'amount': 0.002},
#    {'price': 27968.92, 'amount': 0.008}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-10 12:56:39'),
#   'action': 'sell',
#   'order': [{'price': 28161.93, 'amount': 0.001},
#    {'price': 28160.07, 'amount': 0.0004},
#    {'price': 28160.0, 'amount': 0.0057},
#    {'price': 28159.84, 'amount': 0.0003999999999999993}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-10 12:56:42'),
#   'action': 'sell',
#   'order': [{'price': 28169.06, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-10 12:56:45'),
#   'action': 'buy',
#   'order': [{'price': 28175.0, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-10 15:39:02'),
#   'action': 'sell',
#   'order': [{'price': 28206.93, 'amount': 0.0025}],
#   'position': 0.0075},
#  {'timestamp': Timestamp('2023-05-10 15:39:03'),
#   'action': 'sell',
#   'order': [{'price': 28206.34, 'amount': 0.0025}],
#   'position': 0.005},
#  {'timestamp': Timestamp('2023-05-10 15:39:10'),
#   'action': 'sell',
#   'order': [{'price': 28204.56, 'amount': 0.0025}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-10 15:39:13'),
#   'action': 'sell',
#   'order': [{'price': 28207.32, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-10 17:15:39'),
#   'action': 'buy',
#   'order': [{'price': 27465.64, 'amount': 0.00813},
#    {'price': 27479.48, 'amount': 0.0004},
#    {'price': 27491.82, 'amount': 0.0014700000000000002}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-10 17:15:48'),
#   'action': 'sell',
#   'order': [{'price': 27479.98, 'amount': 0.01}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-10 17:17:00'),
#   'action': 'buy',
#   'order': [{'price': 27150.76, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-10 17:17:02'),
#   'action': 'sell',
#   'order': [{'price': 27063.54, 'amount': 0.00063},
#    {'price': 27063.51, 'amount': 0.00937}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-10 17:17:53'),
#   'action': 'buy',
#   'order': [{'price': 27255.0, 'amount': 0.00082},
#    {'price': 27276.71, 'amount': 0.00918}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-10 17:21:16'),
#   'action': 'sell',
#   'order': [{'price': 26862.08, 'amount': 0.00899},
#    {'price': 26850.57, 'amount': 0.0010100000000000005}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-10 17:21:17'),
#   'action': 'buy',
#   'order': [{'price': 26861.39, 'amount': 0.0075}],
#   'position': 0.0075},
#  {'timestamp': Timestamp('2023-05-10 17:21:18'),
#   'action': 'buy',
#   'order': [{'price': 26872.66, 'amount': 0.0025}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-10 17:39:16'),
#   'action': 'sell',
#   'order': [{'price': 27319.27, 'amount': 0.01}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-10 17:39:33'),
#   'action': 'buy',
#   'order': [{'price': 27323.91, 'amount': 0.00219},
#    {'price': 27323.92, 'amount': 0.00781}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-10 17:48:04'),
#   'action': 'sell',
#   'order': [{'price': 27475.78, 'amount': 0.004},
#    {'price': 27457.19, 'amount': 0.006}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-10 17:48:07'),
#   'action': 'buy',
#   'order': [{'price': 27470.55, 'amount': 0.00254},
#    {'price': 27471.44, 'amount': 0.00746}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-10 17:57:27'),
#   'action': 'sell',
#   'order': [{'price': 27399.6, 'amount': 0.0025}],
#   'position': 0.0075},
#  {'timestamp': Timestamp('2023-05-10 17:57:29'),
#   'action': 'buy',
#   'order': [{'price': 27415.0, 'amount': 0.0025}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-10 19:12:10'),
#   'action': 'sell',
#   'order': [{'price': 27711.23, 'amount': 0.00218},
#    {'price': 27711.0, 'amount': 0.00532}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-10 19:12:21'),
#   'action': 'buy',
#   'order': [{'price': 27708.53, 'amount': 0.005}],
#   'position': 0.0075},
#  {'timestamp': Timestamp('2023-05-10 19:12:23'),
#   'action': 'buy',
#   'order': [{'price': 27718.24, 'amount': 0.0025}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-10 19:12:41'),
#   'action': 'sell',
#   'order': [{'price': 27710.0, 'amount': 0.0075}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-10 19:12:44'),
#   'action': 'sell',
#   'order': [{'price': 27706.97, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-10 19:24:09'),
#   'action': 'buy',
#   'order': [{'price': 27722.96, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-10 19:54:06'),
#   'action': 'sell',
#   'order': [{'price': 27709.11, 'amount': 0.001},
#    {'price': 27704.57, 'amount': 0.009000000000000001}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-10 20:08:02'),
#   'action': 'buy',
#   'order': [{'price': 27738.3, 'amount': 0.005},
#    {'price': 27738.32, 'amount': 0.005}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-10 20:40:26'),
#   'action': 'sell',
#   'order': [{'price': 27906.53, 'amount': 0.001},
#    {'price': 27906.39, 'amount': 0.0005},
#    {'price': 27906.25, 'amount': 0.006}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-10 20:40:37'),
#   'action': 'sell',
#   'order': [{'price': 27886.94, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-10 21:23:48'),
#   'action': 'buy',
#   'order': [{'price': 27625.38, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-10 21:23:51'),
#   'action': 'sell',
#   'order': [{'price': 27541.51, 'amount': 0.01}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-10 21:29:10'),
#   'action': 'buy',
#   'order': [{'price': 27548.81, 'amount': 0.00884},
#    {'price': 27549.0, 'amount': 0.0011599999999999996}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-10 22:05:31'),
#   'action': 'sell',
#   'order': [{'price': 27571.85, 'amount': 0.0075}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-10 22:05:48'),
#   'action': 'sell',
#   'order': [{'price': 27574.48, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-10 22:49:58'),
#   'action': 'buy',
#   'order': [{'price': 27659.88, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-10 22:58:42'),
#   'action': 'sell',
#   'order': [{'price': 27696.3, 'amount': 0.0075}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-10 22:59:03'),
#   'action': 'sell',
#   'order': [{'price': 27698.88, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-10 23:51:51'),
#   'action': 'buy',
#   'order': [{'price': 27663.74, 'amount': 0.0015},
#    {'price': 27664.64, 'amount': 0.00361},
#    {'price': 27664.67, 'amount': 0.00489}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-11 01:18:30'),
#   'action': 'sell',
#   'order': [{'price': 27582.0, 'amount': 0.00237},
#    {'price': 27581.03, 'amount': 0.005129999999999999}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-11 01:19:13'),
#   'action': 'sell',
#   'order': [{'price': 27592.29, 'amount': 0.00217},
#    {'price': 27592.28, 'amount': 0.00033}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-11 10:21:15'),
#   'action': 'buy',
#   'order': [{'price': 27490.07, 'amount': 0.00362},
#    {'price': 27490.11, 'amount': 0.00638}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-11 12:31:01'),
#   'action': 'sell',
#   'order': [{'price': 27528.17, 'amount': 0.001},
#    {'price': 27527.9, 'amount': 0.009000000000000001}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-11 12:49:17'),
#   'action': 'buy',
#   'order': [{'price': 27469.73, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-11 14:05:21'),
#   'action': 'sell',
#   'order': [{'price': 27150.3, 'amount': 0.01}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-11 14:12:02'),
#   'action': 'buy',
#   'order': [{'price': 27261.22, 'amount': 0.00012},
#    {'price': 27261.45, 'amount': 0.00894},
#    {'price': 27261.88, 'amount': 0.0009399999999999999}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-11 15:25:02'),
#   'action': 'sell',
#   'order': [{'price': 27175.99, 'amount': 0.00063},
#    {'price': 27174.2, 'amount': 0.0018700000000000001}],
#   'position': 0.0075},
#  {'timestamp': Timestamp('2023-05-11 15:25:03'),
#   'action': 'buy',
#   'order': [{'price': 27175.36, 'amount': 0.0022},
#    {'price': 27175.37, 'amount': 0.0002999999999999999}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-11 16:00:44'),
#   'action': 'sell',
#   'order': [{'price': 27185.68, 'amount': 0.0025}],
#   'position': 0.0075},
#  {'timestamp': Timestamp('2023-05-11 16:00:45'),
#   'action': 'buy',
#   'order': [{'price': 27188.43, 'amount': 0.0025}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-11 18:49:17'),
#   'action': 'sell',
#   'order': [{'price': 27005.09, 'amount': 0.01}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-11 19:57:45'),
#   'action': 'buy',
#   'order': [{'price': 26886.61, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-11 20:39:03'),
#   'action': 'sell',
#   'order': [{'price': 26955.11, 'amount': 0.005}],
#   'position': 0.005},
#  {'timestamp': Timestamp('2023-05-11 20:39:04'),
#   'action': 'sell',
#   'order': [{'price': 26949.0, 'amount': 0.0025}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-11 20:40:01'),
#   'action': 'sell',
#   'order': [{'price': 26948.0, 'amount': 0.00042},
#    {'price': 26947.61, 'amount': 0.0020800000000000003}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-11 20:46:24'),
#   'action': 'buy',
#   'order': [{'price': 27022.1, 'amount': 0.00123},
#    {'price': 27023.92, 'amount': 0.00349},
#    {'price': 27023.93, 'amount': 0.00528}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-11 20:47:49'),
#   'action': 'sell',
#   'order': [{'price': 27009.6, 'amount': 0.00111},
#    {'price': 27009.59, 'amount': 0.00433},
#    {'price': 27009.49, 'amount': 0.00206}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-11 20:47:59'),
#   'action': 'sell',
#   'order': [{'price': 27020.77, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-11 20:53:46'),
#   'action': 'buy',
#   'order': [{'price': 27042.64, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-12 00:45:01'),
#   'action': 'sell',
#   'order': [{'price': 27036.02, 'amount': 0.002},
#    {'price': 27035.01, 'amount': 0.0055}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-12 00:45:52'),
#   'action': 'sell',
#   'order': [{'price': 27030.79, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-12 04:04:25'),
#   'action': 'buy',
#   'order': [{'price': 26666.12, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-12 05:55:01'),
#   'action': 'sell',
#   'order': [{'price': 26274.69, 'amount': 0.01}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-12 05:57:01'),
#   'action': 'buy',
#   'order': [{'price': 26311.7, 'amount': 0.00199},
#    {'price': 26312.55, 'amount': 0.00391},
#    {'price': 26312.56, 'amount': 0.0040999999999999995}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-12 07:18:15'),
#   'action': 'sell',
#   'order': [{'price': 26320.89, 'amount': 0.01}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-12 08:38:33'),
#   'action': 'buy',
#   'order': [{'price': 26326.27, 'amount': 0.00737},
#    {'price': 26326.29, 'amount': 0.0026300000000000004}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-12 09:08:04'),
#   'action': 'sell',
#   'order': [{'price': 26327.99, 'amount': 0.0075}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-12 09:09:04'),
#   'action': 'sell',
#   'order': [{'price': 26338.49, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-12 09:50:02'),
#   'action': 'buy',
#   'order': [{'price': 26440.87, 'amount': 0.002},
#    {'price': 26441.3, 'amount': 0.008}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-12 12:15:48'),
#   'action': 'sell',
#   'order': [{'price': 26415.42, 'amount': 0.00246},
#    {'price': 26415.41, 'amount': 4.0000000000000105e-05}],
#   'position': 0.0075},
#  {'timestamp': Timestamp('2023-05-12 12:15:53'),
#   'action': 'buy',
#   'order': [{'price': 26405.84, 'amount': 0.0025}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-12 12:15:54'),
#   'action': 'sell',
#   'order': [{'price': 26402.26, 'amount': 0.00099},
#    {'price': 26401.1, 'amount': 0.00114},
#    {'price': 26401.09, 'amount': 0.0003700000000000001}],
#   'position': 0.0075},
#  {'timestamp': Timestamp('2023-05-12 12:15:56'),
#   'action': 'sell',
#   'order': [{'price': 26401.51, 'amount': 0.00071},
#    {'price': 26401.14, 'amount': 0.00179}],
#   'position': 0.005},
#  {'timestamp': Timestamp('2023-05-12 12:16:01'),
#   'action': 'sell',
#   'order': [{'price': 26398.54, 'amount': 0.005}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-12 12:26:04'),
#   'action': 'buy',
#   'order': [{'price': 26420.85, 'amount': 0.00188},
#    {'price': 26420.86, 'amount': 0.00812}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-12 19:25:56'),
#   'action': 'sell',
#   'order': [{'price': 26057.93, 'amount': 0.00377},
#    {'price': 26048.0, 'amount': 0.00623}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-12 19:25:57'),
#   'action': 'buy',
#   'order': [{'price': 26011.52, 'amount': 0.0075}],
#   'position': 0.0075},
#  {'timestamp': Timestamp('2023-05-12 19:25:58'),
#   'action': 'sell',
#   'order': [{'price': 25973.44, 'amount': 0.0075}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-12 19:33:06'),
#   'action': 'buy',
#   'order': [{'price': 26033.29, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-12 19:49:52'),
#   'action': 'sell',
#   'order': [{'price': 26167.18, 'amount': 0.00171},
#    {'price': 26167.17, 'amount': 0.00343},
#    {'price': 26167.16, 'amount': 0.00236}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-12 19:49:59'),
#   'action': 'sell',
#   'order': [{'price': 26172.0, 'amount': 0.00042},
#    {'price': 26169.04, 'amount': 0.0020800000000000003}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-12 19:50:30'),
#   'action': 'buy',
#   'order': [{'price': 26170.04, 'amount': 0.00229},
#    {'price': 26171.94, 'amount': 0.00049},
#    {'price': 26171.95, 'amount': 0.00722}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-12 19:56:24'),
#   'action': 'sell',
#   'order': [{'price': 26441.5, 'amount': 0.01}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-12 19:56:27'),
#   'action': 'buy',
#   'order': [{'price': 26461.57, 'amount': 0.002},
#    {'price': 26463.99, 'amount': 0.008}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-12 20:56:18'),
#   'action': 'sell',
#   'order': [{'price': 26449.59, 'amount': 0.005}],
#   'position': 0.005},
#  {'timestamp': Timestamp('2023-05-12 20:56:20'),
#   'action': 'sell',
#   'order': [{'price': 26450.76, 'amount': 0.0025}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-12 20:57:03'),
#   'action': 'sell',
#   'order': [{'price': 26453.0, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-12 21:01:03'),
#   'action': 'buy',
#   'order': [{'price': 26502.99, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-12 21:10:20'),
#   'action': 'sell',
#   'order': [{'price': 26594.96, 'amount': 0.00045},
#    {'price': 26593.0, 'amount': 0.00705}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-12 21:10:21'),
#   'action': 'sell',
#   'order': [{'price': 26598.02, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-12 21:13:19'),
#   'action': 'buy',
#   'order': [{'price': 26749.47, 'amount': 0.00094},
#    {'price': 26749.48, 'amount': 0.00906}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-12 22:12:08'),
#   'action': 'sell',
#   'order': [{'price': 26890.64, 'amount': 0.0032},
#    {'price': 26887.69, 'amount': 0.0043}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-12 22:12:09'),
#   'action': 'sell',
#   'order': [{'price': 26899.83, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-12 22:14:22'),
#   'action': 'buy',
#   'order': [{'price': 26863.88, 'amount': 0.00229},
#    {'price': 26865.0, 'amount': 0.00397},
#    {'price': 26865.09, 'amount': 0.0037400000000000003}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-13 01:08:12'),
#   'action': 'sell',
#   'order': [{'price': 26831.37, 'amount': 0.01}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-13 01:08:49'),
#   'action': 'buy',
#   'order': [{'price': 26838.3, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-13 01:18:26'),
#   'action': 'sell',
#   'order': [{'price': 26954.57, 'amount': 0.01}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-13 01:19:00'),
#   'action': 'buy',
#   'order': [{'price': 26965.6, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-13 05:21:33'),
#   'action': 'sell',
#   'order': [{'price': 26856.68, 'amount': 0.00043},
#    {'price': 26853.6, 'amount': 0.00707}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-13 05:21:38'),
#   'action': 'sell',
#   'order': [{'price': 26875.84, 'amount': 0.00134},
#    {'price': 26874.45, 'amount': 0.00116}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-13 18:49:03'),
#   'action': 'buy',
#   'order': [{'price': 26953.74, 'amount': 0.0025}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-13 18:49:04'),
#   'action': 'sell',
#   'order': [{'price': 26966.42, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-13 19:13:10'),
#   'action': 'buy',
#   'order': [{'price': 26885.12, 'amount': 0.0018},
#    {'price': 26885.66, 'amount': 0.00251},
#    {'price': 26886.84, 'amount': 0.00073},
#    {'price': 26891.84, 'amount': 0.0024600000000000004}],
#   'position': 0.0075},
#  {'timestamp': Timestamp('2023-05-13 19:13:11'),
#   'action': 'buy',
#   'order': [{'price': 26890.15, 'amount': 0.0025}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-13 19:23:53'),
#   'action': 'sell',
#   'order': [{'price': 26944.29, 'amount': 0.0025}],
#   'position': 0.0075},
#  {'timestamp': Timestamp('2023-05-13 19:23:55'),
#   'action': 'sell',
#   'order': [{'price': 26941.46, 'amount': 0.0025}],
#   'position': 0.005},
#  {'timestamp': Timestamp('2023-05-13 19:23:59'),
#   'action': 'sell',
#   'order': [{'price': 26942.7, 'amount': 0.00119},
#    {'price': 26941.92, 'amount': 0.00131}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-13 19:24:00'),
#   'action': 'sell',
#   'order': [{'price': 26940.0, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-13 21:28:05'),
#   'action': 'buy',
#   'order': [{'price': 26953.88, 'amount': 0.00394},
#    {'price': 26953.89, 'amount': 0.00606}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-13 22:11:50'),
#   'action': 'sell',
#   'order': [{'price': 26865.01, 'amount': 0.01}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-14 01:32:29'),
#   'action': 'buy',
#   'order': [{'price': 26745.98, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-14 01:39:28'),
#   'action': 'sell',
#   'order': [{'price': 26733.74, 'amount': 0.001},
#    {'price': 26732.42, 'amount': 0.00221},
#    {'price': 26732.32, 'amount': 0.0042899999999999995}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-14 01:40:07'),
#   'action': 'sell',
#   'order': [{'price': 26739.5, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-14 02:04:01'),
#   'action': 'buy',
#   'order': [{'price': 26753.97, 'amount': 0.00224},
#    {'price': 26754.05, 'amount': 0.00026000000000000025}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-14 02:05:27'),
#   'action': 'sell',
#   'order': [{'price': 26750.3, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-14 14:44:25'),
#   'action': 'buy',
#   'order': [{'price': 26926.67, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-14 15:16:38'),
#   'action': 'sell',
#   'order': [{'price': 27120.45, 'amount': 0.005}],
#   'position': 0.005},
#  {'timestamp': Timestamp('2023-05-14 15:16:42'),
#   'action': 'sell',
#   'order': [{'price': 27110.89, 'amount': 0.00139},
#    {'price': 27110.88, 'amount': 0.00111}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-14 15:16:44'),
#   'action': 'sell',
#   'order': [{'price': 27101.21, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-14 15:18:16'),
#   'action': 'buy',
#   'order': [{'price': 27141.36, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-14 16:11:04'),
#   'action': 'sell',
#   'order': [{'price': 27132.7, 'amount': 0.0025}],
#   'position': 0.0075},
#  {'timestamp': Timestamp('2023-05-14 16:11:06'),
#   'action': 'sell',
#   'order': [{'price': 27130.05, 'amount': 0.0025}],
#   'position': 0.005},
#  {'timestamp': Timestamp('2023-05-14 16:11:07'),
#   'action': 'buy',
#   'order': [{'price': 27130.75, 'amount': 0.0025}],
#   'position': 0.0075},
#  {'timestamp': Timestamp('2023-05-14 16:11:09'),
#   'action': 'sell',
#   'order': [{'price': 27127.74, 'amount': 0.00044},
#    {'price': 27127.46, 'amount': 0.00166},
#    {'price': 27127.45, 'amount': 0.0004000000000000002}],
#   'position': 0.005},
#  {'timestamp': Timestamp('2023-05-14 16:11:20'),
#   'action': 'sell',
#   'order': [{'price': 27114.0, 'amount': 0.0025}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-14 16:11:21'),
#   'action': 'sell',
#   'order': [{'price': 27110.51, 'amount': 0.001},
#    {'price': 27110.37, 'amount': 0.0015}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-14 17:27:48'),
#   'action': 'buy',
#   'order': [{'price': 26977.3, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-14 21:15:30'),
#   'action': 'sell',
#   'order': [{'price': 26951.84, 'amount': 0.00185},
#    {'price': 26951.83, 'amount': 0.00315}],
#   'position': 0.005},
#  {'timestamp': Timestamp('2023-05-14 21:16:03'),
#   'action': 'sell',
#   'order': [{'price': 26954.25, 'amount': 0.0025}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-14 21:16:04'),
#   'action': 'sell',
#   'order': [{'price': 26954.28, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-15 01:25:00'),
#   'action': 'buy',
#   'order': [{'price': 27029.36, 'amount': 0.001},
#    {'price': 27031.77, 'amount': 0.004},
#    {'price': 27032.93, 'amount': 0.005000000000000001}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-15 01:54:25'),
#   'action': 'sell',
#   'order': [{'price': 27293.21, 'amount': 0.0067},
#    {'price': 27292.97, 'amount': 0.0007999999999999995}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-15 01:54:37'),
#   'action': 'sell',
#   'order': [{'price': 27279.72, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-15 05:01:32'),
#   'action': 'buy',
#   'order': [{'price': 27310.38, 'amount': 0.0025}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-15 05:01:34'),
#   'action': 'sell',
#   'order': [{'price': 27308.08, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-15 05:46:02'),
#   'action': 'buy',
#   'order': [{'price': 27365.0, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-15 05:55:01'),
#   'action': 'sell',
#   'order': [{'price': 27381.74, 'amount': 0.0075}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-15 05:55:51'),
#   'action': 'sell',
#   'order': [{'price': 27345.06, 'amount': 0.001},
#    {'price': 27345.02, 'amount': 0.0015}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-15 06:16:02'),
#   'action': 'buy',
#   'order': [{'price': 27374.0, 'amount': 0.01}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-15 09:01:34'),
#   'action': 'sell',
#   'order': [{'price': 27473.52, 'amount': 0.0025}],
#   'position': 0.0075},
#  {'timestamp': Timestamp('2023-05-15 09:01:35'),
#   'action': 'sell',
#   'order': [{'price': 27472.8, 'amount': 0.00187},
#    {'price': 27472.72, 'amount': 0.0006300000000000001}],
#   'position': 0.005},
#  {'timestamp': Timestamp('2023-05-15 09:02:01'),
#   'action': 'buy',
#   'order': [{'price': 27460.94, 'amount': 0.0025}],
#   'position': 0.0075},
#  {'timestamp': Timestamp('2023-05-15 09:02:03'),
#   'action': 'buy',
#   'order': [{'price': 27460.24, 'amount': 0.0025}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-15 14:53:40'),
#   'action': 'sell',
#   'order': [{'price': 27518.1, 'amount': 0.00111},
#    {'price': 27516.65, 'amount': 0.00086},
#    {'price': 27516.56, 'amount': 0.00553}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-15 14:53:45'),
#   'action': 'sell',
#   'order': [{'price': 27518.2, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-15 14:54:48'),
#   'action': 'buy',
#   'order': [{'price': 27500.85, 'amount': 0.00095},
#    {'price': 27502.22, 'amount': 0.00905}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-15 15:54:34'),
#   'action': 'sell',
#   'order': [{'price': 27397.58, 'amount': 0.0025}],
#   'position': 0.0075},
#  {'timestamp': Timestamp('2023-05-15 15:54:36'),
#   'action': 'buy',
#   'order': [{'price': 27397.64, 'amount': 0.0025}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-15 17:13:18'),
#   'action': 'sell',
#   'order': [{'price': 27643.84, 'amount': 0.0075}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-15 17:13:34'),
#   'action': 'sell',
#   'order': [{'price': 27648.37, 'amount': 0.0025}],
#   'position': 0.0},
#  {'timestamp': Timestamp('2023-05-15 17:57:30'),
#   'action': 'buy',
#   'order': [{'price': 27536.96, 'amount': 0.002},
#    {'price': 27537.42, 'amount': 0.008}],
#   'position': 0.01},
#  {'timestamp': Timestamp('2023-05-15 19:45:51'),
#   'action': 'sell',
#   'order': [{'price': 27402.2, 'amount': 0.0075}],
#   'position': 0.0025},
#  {'timestamp': Timestamp('2023-05-15 19:45:55'),
#   'action': 'sell',
#   'order': [{'price': 27399.66, 'amount': 0.0025}],
#   'position': 0.0}]

# %%
# def __init__(self, market_information, strategy,commission_rate=0.00015):

# market information should be a data frame that consist of 21 columns(timedstamp &  5-level ask bid's price and size)
# stategy: a list of dictionary consisting of 3 keys: timestamp, action (buy or sell) and dictionary indicating the level
# price and amount of the conducted orders

market_information = data
commission_rate = commission_fee
# strategy = strategy

# order in strategy[{'timestamp':,'action':,'order':[{'price':,'amount':},{'price':,'amount':},...],'position':}]
# the strategy should be a list of market order containing the executed price, amount the agent's position after conducting the trade
# check the pricing the problem
price_timing = [price["timestamp"] for price in strategy]
assert max(price_timing) <= max(market_information.timestamp)
# check the price is legal
for timestamp in market_information.timestamp.unique():
    price_single_timestamp = market_information[
        market_information["timestamp"] == timestamp
    ]

    assert (
        price_single_timestamp["ask1_price"].values[0]
        >= price_single_timestamp["bid1_price"].values[0]
    )
# check the strategy opening position is whether is over rated and place correctly
# 对于买单我们要检查他的买入价格的下限应该符合ask1 price
for stack_order in strategy:
    timestamp = stack_order["timestamp"]
    current_market_information = market_information[
        market_information["timestamp"] == timestamp
    ]
    assert stack_order["action"] in ["buy", "sell"]
    if stack_order["action"] == "buy":
        list_order = stack_order["order"]
        level_number = len(list_order)
        for i in range(level_number):
            assert (
                list_order[i]["price"]
                == current_market_information["ask{}_price".format(i + 1)].values[0]
            )
            assert (
                list_order[i]["amount"]
                <= current_market_information["ask{}_size".format(i + 1)].values[0]
            )
    elif stack_order["action"] == "sell":
        list_order = stack_order["order"]
        level_number = len(list_order)
        for i in range(level_number):
            assert (
                list_order[i]["price"]
                == current_market_information["bid{}_price".format(i + 1)].values[
                    0
                ]  # ？？？？？？？？？bid0_price  format(i)
            )
            assert (
                list_order[i]["amount"]
                <= current_market_information["bid{}_size".format(i + 1)].values[0]
            )
# check the trace of the position in the trading process is legal or not. it always should be 0 at the start and end of the trading process
if strategy[-1]["position"] != 0:
    last_position = strategy[-1]["position"]
    warnings.warn(
        "the final position of the strategy is not zero, we force the agent to close its position in the last timestamp"
    )
    last_market_information = market_information[
        market_information["timestamp"] == max(market_information["timestamp"].unique())
    ]
    size_sum = 0
    if (
        last_position
        > last_market_information["bid1_size"].values[0]
        + last_market_information["bid2_size"].values[0]
        + last_market_information["bid3_size"].values[0]
        + last_market_information["bid4_size"].values[0]
        + last_market_information["bid5_size"].values[0]
    ):
        warnings.warn(
            "we barely trade at this timstamp instantly because there is no enough liquidity in the market,\
        we force the agent to close its position in the last timestamp by expanding the last level's size"
        )
        last_market_information["bid5_size"] = last_position - (
            last_market_information["bid1_size"].values[0]
            + last_market_information["bid2_size"].values[0]
            + last_market_information["bid3_size"].values[0]
            + last_market_information["bid4_size"].values[0]
        )
    for i in range(5):
        size_sum += last_market_information["bid{}_size".format(i + 1)].values[0]
        if last_position <= size_sum:
            break
    level_order_size_list = []
    order_remaining = last_position
    for j in range(i + 1):
        level_order_size_list.append(
            {
                "price": last_market_information["bid{}_price".format(j + 1)].values[0],
                "amount": min(
                    order_remaining,
                    last_market_information["bid{}_size".format(j + 1)].values[0],
                ),
            }
        )
        order_remaining = (
            order_remaining
            - last_market_information["bid{}_size".format(j + 1)].values[0]
        )
    strategy.append(
        {
            "timestamp": last_market_information["timestamp"].values[0],
            "action": "sell",
            "order": level_order_size_list,
            "position": 0,
        }
    )

# %%
def analysis_behavior(selected_strategy):
    # 现确定总共的开闭仓的次数 selected strategy 起码开头和结尾的position应该为0
    opening_strategy_timestamp_list = []
    closing_strategy_timestamp_list = []

    for stack_order in selected_strategy:
        if stack_order["action"] == "buy":
            order_size = 0
            for order in stack_order["order"]:
                order_size += order["amount"]
            if order_size == stack_order["position"]:
                opening_strategy_timestamp_list.append(stack_order["timestamp"])
        elif stack_order["action"] == "sell":
            if stack_order["position"] == 0:
                closing_strategy_timestamp_list.append(stack_order["timestamp"])
    print("opening_strategy_timestamp_list", opening_strategy_timestamp_list)
    print("closing_strategy_timestamp_list", closing_strategy_timestamp_list)
    assert len(opening_strategy_timestamp_list) == len(
        closing_strategy_timestamp_list
    )  # 确保开仓和平仓的次数相同
    trade_timestamp_list = list(
        zip(opening_strategy_timestamp_list, closing_strategy_timestamp_list)
    )

    # 1. 计算每次交易的收益率以及开仓到平仓的时间
    total_return_rate = 0
    total_duration = timedelta()
    total_mdd = 0
    count_pos_return_rate = 0

    for open_time, close_time in trade_timestamp_list:
        assert open_time < close_time
        single_trade_strategy = []
        for selected_stack_order in selected_strategy:
            if (
                selected_stack_order["timestamp"] >= open_time
                and selected_stack_order["timestamp"] <= close_time
            ):
                single_trade_strategy.append(selected_stack_order)
        cash_flow = []
        # print("single_trade_strategy", single_trade_strategy)
        # 计算每次交易的现金流的变化
        for stack_order in single_trade_strategy:
            # print("stack_order", stack_order)
            total_value = 0
            for order in stack_order["order"]:
                total_value += order["price"] * order["amount"]
            if stack_order["action"] == "buy":
                total_value = -total_value
                total_value = total_value * (1 + commission_rate)
            if stack_order["action"] == "sell":
                total_value = total_value * (1 - commission_rate)
            cash_flow.append(total_value)
        cash_record = [sum(cash_flow[: i + 1]) for i in range(len(cash_flow))]
        final_cash = cash_record[-1]
        require_money = -min(cash_record)
        # 计算每次交易的收益率和持仓时间
        return_rate = final_cash / require_money
        total_return_rate += return_rate

        if return_rate > 0:
            count_pos_return_rate += 1
            total_duration += close_time - open_time

        total_duration += close_time - open_time
        # TODO 根据bid1 price进行结算，每次持仓过程中的maxdrawdown
        position_record = []
        timestamp_record = []
        trade_position_record = []
        cash_accmulative_record = []
        for stack_order in single_trade_strategy:
            timestamp_record.append(stack_order["timestamp"])
            position_record.append(stack_order["position"])
        corresponding_market_timestamp = [
            timestamp
            for timestamp in market_information["timestamp"].unique()
            if timestamp >= open_time and timestamp <= close_time
        ]
        assert len(timestamp_record) == len(position_record)
        assert len(timestamp_record) == len(cash_record)

        for i in range(len(timestamp_record) - 1):
            time_point = [
                timestamp
                for timestamp in market_information["timestamp"].unique()
                if (
                    timestamp >= timestamp_record[i]
                    and timestamp < timestamp_record[i + 1]
                )
            ]
            cash_accmulative_record.append(cash_record[i] + require_money)
            for j in range(len(time_point)):
                trade_position_record.append(position_record[i])
            for k in range(len(time_point)):
                cash_accmulative_record.append(cash_accmulative_record[-1])
        trade_position_record.append(0)
        cash_accmulative_record.append(cash_record[i + 1] + require_money)
        # print("cash_accmulative_record", cash_accmulative_record)

        # trade_position_record.append(0)
        corresponding_market_information = market_information[
            market_information["timestamp"].isin(corresponding_market_timestamp)
        ]
        # print("trade_position_record_length", len(trade_position_record))
        # print("corresponding_market_information_length", len(corresponding_market_information))
        # if len(trade_position_record) != len(corresponding_market_information):
        #     print("trade_position_record", trade_position_record)
        #     print("corresponding_market_information", corresponding_market_information)

        assert len(trade_position_record) == len(corresponding_market_information)

        position_value_record = [
            position * single_value
            for position, single_value in zip(
                trade_position_record,
                corresponding_market_information["bid1_price"].values,
            )
        ]
        total_value_record = [
            cash + position_value
            for cash, position_value in zip(
                cash_accmulative_record, position_value_record
            )
        ]
        mdd = 0
        peak = total_value_record[0]
        for value in total_value_record:
            if value > peak:
                peak = value
            dd = (peak - value) / peak
            if dd > mdd:
                mdd = dd
        total_mdd += mdd

    mean_return_rate = total_return_rate / len(trade_timestamp_list)
    mean_duration = total_duration / len(trade_timestamp_list)
    mean_mdd = total_mdd / len(trade_timestamp_list)
    # TODO 你还需要计算这段策略中的胜率（trade中return rate大于0的数量/trade的总数量）
    win_rate = count_pos_return_rate / len(trade_timestamp_list)
    return mean_return_rate, mean_duration, mean_mdd, win_rate

# %%
def calculate_metric(selected_timestamp: list):
    # selected trade is part of the strategy that we want to calculate the metric,
    # its position do not have to end or start with 0
    # selected_timestamp is a 2-element list indicating the start and end of the timestamp
    selected_timestamp.sort()
    assert len(selected_timestamp) == 2
    selected_market = market_information[
        (market_information["timestamp"] >= selected_timestamp[0])
        & (market_information["timestamp"] <= selected_timestamp[1])
    ]
    selected_strategy = [
        item
        for item in strategy
        if selected_timestamp[0] <= item["timestamp"] <= selected_timestamp[1]
    ]
    first_trade = selected_strategy[0]
    first_trade_size = sum([level["amount"] for level in first_trade["order"]])
    if first_trade["action"] == "buy":
        first_trade_size = -first_trade_size

    initial_posotion = selected_strategy[0]["position"] + first_trade_size
    assert initial_posotion >= 0
    # 默认第一步自动补仓 用bid1买的 看啥情况
    cash_flow = [
        -initial_posotion
        * market_information[market_information["timestamp"] == selected_timestamp[0]][
            "bid1_price"
        ].values[0]
    ]
    for stack_order in selected_strategy:
        total_value = 0
        for order in stack_order["order"]:
            total_value += order["price"] * order["amount"]
            if stack_order["action"] == "buy":
                total_value = -total_value
                total_value = total_value * (1 + commission_rate)
            if stack_order["action"] == "sell":
                total_value = total_value * (1 - commission_rate)
            cash_flow.append(total_value)
            cash_flow.append(total_value)

    cash_record = [sum(cash_flow[: i + 1]) for i in range(len(cash_flow))]
    # print("cash_record", cash_record)
    # cash record 总计来讲现金流的list
    require_money = -min(cash_record)
    # 最小的现金流 （最缺钱的 就是require money）
    position = initial_posotion
    position_market_record = []
    cash_market_record = []
    for timestamp in selected_market.timestamp.unique():
        matching_strategy = None
        for item in selected_strategy:
            if item["timestamp"] == timestamp:
                matching_strategy = item
                break
        if matching_strategy:
            current_position = matching_strategy["position"]
            position = current_position
        else:
            current_position = position
        position_market_record.append(current_position)
    inital_cash = require_money - cash_flow[0]
    cash = inital_cash
    for timestamp in selected_market.timestamp.unique():
        matching_strategy = next(
            (item for item in selected_strategy if item["timestamp"] == timestamp),
            None,
        )
        if matching_strategy:
            total_value = 0
            for order in matching_strategy["order"]:
                total_value += order["price"] * order["amount"]
            if matching_strategy["action"] == "buy":
                total_value = -total_value
                total_value = total_value * (1 + commission_rate)
            if matching_strategy["action"] == "sell":
                total_value = total_value * (1 - commission_rate)
            cash_flow.append(total_value)
            current_cash = cash + total_value
            cash = current_cash
            # print('total_value',total_value)
        else:
            current_cash = cash
        # print("current_cash", current_cash)
        cash_market_record.append(current_cash)
    assert len(position_market_record) == len(cash_market_record)
    # print(len(selected_market))
    # print(len(position_market_record))
    assert len(position_market_record) == len(selected_market)
    selected_market_price = selected_market["bid1_price"].values
    position_value_record = [
        position * single_value
        for position, single_value in zip(position_market_record, selected_market_price)
    ]
    # print("require_money", require_money)

    total_value_record = [
        cash + position_value
        for cash, position_value in zip(cash_market_record, position_value_record)
    ]
    # print("cash", cash_market_record)
    tr = total_value_record[-1] / total_value_record[0] - 1
    mdd = 0
    peak = total_value_record[0]
    for value in total_value_record:
        if value > peak:
            peak = value
        dd = (peak - value) / peak
        if dd > mdd:
            mdd = dd
    cr = tr / mdd
    return tr, mdd, cr

# %%
def analysis_along_time_dynamics(
    path, num_dynamics, num_seg, selected_timestamp: list
):
    # TODO 给定段时间，先把这段时间内的市场状态划分成num_dynamics个市场状态
    # TODO 根据策略 用开平仓的次数来划分时间（总开平仓次数）
    # TODO 两维度从时间和市场状态 计算胜率，收益率，持仓时间，最大回撤，calmar ratio，已经开仓量和平仓量占总开仓量和平仓量的百分比

    selected_market = data[
        (data["timestamp"] >= selected_timestamp[0])
        & (data["timestamp"] <= selected_timestamp[1])
    ]

    model = Linear_Market_Dynamics_Model(
        data=selected_market.reset_index(), dynamic_number=num_dynamics
    )
    model.run(path)
    df_label = pd.read_feather(path + "/df_label.feather")
    assert len(selected_market) == len(df_label)

    opening_count_seg = [[0] * num_dynamics] * num_seg
    closing_count_seg = [[0] * num_dynamics] * num_seg
    opening_amount_seg = [[0] * num_dynamics] * num_seg
    closing_amount_seg = [[0] * num_dynamics] * num_seg

    opening_strategy_timestamp_list = []
    closing_strategy_timestamp_list = []

    for stack_order in strategy:  
        print(stack_order)
        if stack_order["action"] == "buy":
            order_size = 0
            for order in stack_order["order"]:
                order_size += order["amount"]
            if abs(order_size-stack_order["position"]) <0.000001:
                print("add buy/opening record {}".format(stack_order["timestamp"]))
                opening_strategy_timestamp_list.append(stack_order["timestamp"])
        elif stack_order["action"] == "sell":
            if stack_order["position"] == 0:
                closing_strategy_timestamp_list.append(stack_order["timestamp"])
                print("add sell/closing record {}".format(stack_order["timestamp"]))
    
    print()
    print(opening_strategy_timestamp_list)
    print(closing_strategy_timestamp_list)
    print(len(opening_strategy_timestamp_list))
    print(len(closing_strategy_timestamp_list))
    
    assert len(opening_strategy_timestamp_list) == len(closing_strategy_timestamp_list)
    print(len(opening_strategy_timestamp_list))
    assert len(opening_strategy_timestamp_list) >= num_seg
    num_trade_seg = int(len(opening_strategy_timestamp_list) / num_seg)

    def calculate(local_selected_timestamp, path):
        tr, mdd, cr = calculate_metric(local_selected_timestamp)

        selected_strategy = [  # 进行交易的market time
            item
            for item in strategy
            if local_selected_timestamp[0]
            <= item["timestamp"]
            <= local_selected_timestamp[1]
        ]
        mean_return_rate, mean_duration, mean_mdd, win_rate = analysis_behavior(
            selected_strategy
        )

        print(
            "in the {}th segment, the total return rate is {}, the max drawdown is {}, the calmar ratio is {}, the mean return rate, mean duration, mean max drawdown, win rate is as follow".format(
                i, tr, mdd, cr, mean_return_rate, mean_duration, mean_mdd, win_rate
            )
        )

        metrics_path = path + "/metrics_segment{}".format(i) +".csv"
        metrics_name = [
            "segmentId",
            "total return rate",
            "max drawdown",
            "calmar ratio",
            "mean return rate",
            "mean duration",
            "mean max drawdown",
            "win rate",
        ]
        metrics = [
            {
                "segmentId": i,
                "total return rate": tr,
                "max drawdown": mdd,
                "calmar ratio": cr,
                "mean return rate": mean_return_rate,
                "mean duration": mean_duration,
                "mean max drawdown": mean_mdd,
                "win rate": win_rate,
            }
        ]

        with open(metrics_path, "w") as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=metrics_name)
            writer.writeheader()
            writer.writerows(metrics)

    def along_dynamics(local_selected_timestamp, index_seg):
        # selected_market = data[
        #     (data["timestamp"] >= local_selected_timestamp[0])
        #     & (data["timestamp"] <= local_selected_timestamp[1])
        # ]
        selected_strategy = [  # 进行交易的market time
            item
            for item in strategy
            if local_selected_timestamp[0]
            <= item["timestamp"]
            <= local_selected_timestamp[1]
        ]

        opening_strategy_timestamp_list = []
        closing_strategy_timestamp_list = []
        opening_count = [0] * 5
        closing_count = [0] * 5
        opening_amount = [0] * 5
        closing_amount = [0] * 5

        for stack_order in selected_strategy:
            # print(stack_order)
            if stack_order["action"] == "buy":
                order_size = 0
                for order in stack_order["order"]:
                    order_size += order["amount"]
                label_index = df_label[
                    df_label["timestamp"] == stack_order["timestamp"]
                ]["label"].values[
                    0
                ]  # 获取label
                opening_amount[label_index] += sum(
                    level["amount"] for level in stack_order["order"]
                )  # 记录开仓总量至对应label
                if order_size == stack_order["position"]:
                    # print(stack_order["timestamp"])
                    opening_strategy_timestamp_list.append(stack_order["timestamp"])
                    opening_count[label_index] += 1  # 记录对应label的开仓次数
                    # print("add buy count {} for label {}".format(opening_count[label_index], label_index))
                # sumtemp = sum( level['amount'] for level in stack_order['order'])
                # print("add buy amount {} for label {}".format(sumtemp, label_index))

            elif stack_order["action"] == "sell":
                label_index = df_label[
                    df_label["timestamp"] == stack_order["timestamp"]
                ]["label"].values[0]
                closing_amount[label_index] += sum(
                    level["amount"] for level in stack_order["order"]
                )
                if stack_order["position"] == 0:
                    # print(stack_order["timestamp"])
                    closing_strategy_timestamp_list.append(stack_order["timestamp"])
                    closing_count[label_index] += 1
                    # print("add sell count {} for label {}".format(closing_count[label_index], label_index))
                # sumtemp = sum( level['amount'] for level in stack_order['order'])
                # print("add sell record {} for label {}".format(sumtemp, label_index))

        opening_count_seg[index_seg] = opening_count
        closing_count_seg[index_seg] = closing_count
        opening_amount_seg[index_seg] = opening_amount
        closing_amount_seg[index_seg] = closing_amount

    for i in range(num_seg):
        # print()
        # print("this is segment {}".format(i))
        start_market_time = 0
        if i == 0:
            start_market_time = opening_strategy_timestamp_list[num_trade_seg * 0]
        else:
            for row_index, row in data.iterrows():
                if (
                    row["timestamp"]
                    > closing_strategy_timestamp_list[num_trade_seg * i]
                ):
                    start_market_time = row["timestamp"]
                    break

        if i == num_seg - 1:
            close_market_time = closing_strategy_timestamp_list[-1]
        else:
            close_market_time = closing_strategy_timestamp_list[num_trade_seg * (i + 1)]

        phase_selected_timestamp = [start_market_time, close_market_time]
        calculate(phase_selected_timestamp, path)
        along_dynamics(phase_selected_timestamp, i)


    return (
        opening_count_seg,
        closing_count_seg,
        opening_amount_seg,
        closing_amount_seg,
    )

# %%
(
    opening_count_seg,
    closing_count_seg,
    opening_amount_seg,
    closing_amount_seg,
) = analysis_along_time_dynamics(path, num_dynamics, num_seg, selected_timestamp)
# Out:
# labeling start
# ../best_result/BTCT/data/valid_processed.feather
# start fitting
# Only merge dynamic <= distance:  1
# merging round:  1 current number of segments:  1035
#   0%|          | 0/1035 [00:00<?, ?it/s]/home/mlqin/anaconda3/envs/HFT/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/mlqin/anaconda3/envs/HFT/lib/python3.8/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 100%|██████████| 1035/1035 [00:01<00:00, 639.88it/s]
# All distance statistics:
# count    2036.000000
# mean        0.000403
# std         0.000312
# min         0.000016
# 25%         0.000208
# 50%         0.000331
# 75%         0.000489
# max         0.004018
# dtype: float64
# Your merging_threshold is:  0.0003
# Merge prohibit times by merging_dynamic_constraint: 523
# merging round:  2 current number of segments:  720
#   0%|          | 0/1035 [00:00<?, ?it/s]/home/mlqin/anaconda3/envs/HFT/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/mlqin/anaconda3/envs/HFT/lib/python3.8/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 100%|██████████| 1035/1035 [00:01<00:00, 744.99it/s]
# All distance statistics:
# count    1414.000000
# mean        0.000483
# std         0.000335
# min         0.000063
# 25%         0.000288
# 50%         0.000399
# 75%         0.000569
# max         0.004018
# dtype: float64
# Your merging_threshold is:  0.0003
# Merge prohibit times by merging_dynamic_constraint: 321
# merging round:  3 current number of segments:  660
#   5%|▌         | 53/1035 [00:00<00:01, 525.34it/s]/home/mlqin/anaconda3/envs/HFT/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/mlqin/anaconda3/envs/HFT/lib/python3.8/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 100%|██████████| 1035/1035 [00:01<00:00, 693.29it/s]
# All distance statistics:
# count    1294.000000
# mean        0.000507
# std         0.000339
# min         0.000079
# 25%         0.000311
# 50%         0.000419
# 75%         0.000607
# max         0.004018
# dtype: float64
# Your merging_threshold is:  0.0003
# Merge prohibit times by merging_dynamic_constraint: 255
# merging round:  4 current number of segments:  632
#   5%|▍         | 47/1035 [00:00<00:02, 468.55it/s]/home/mlqin/anaconda3/envs/HFT/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/mlqin/anaconda3/envs/HFT/lib/python3.8/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 100%|██████████| 1035/1035 [00:01<00:00, 656.39it/s]
# All distance statistics:
# count    1240.000000
# mean        0.000518
# std         0.000342
# min         0.000079
# 25%         0.000318
# 50%         0.000429
# 75%         0.000618
# max         0.004018
# dtype: float64
# Your merging_threshold is:  0.0003
# Merge prohibit times by merging_dynamic_constraint: 241
# merging round:  5 current number of segments:  622
#   4%|▍         | 43/1035 [00:00<00:02, 422.85it/s]/home/mlqin/anaconda3/envs/HFT/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/mlqin/anaconda3/envs/HFT/lib/python3.8/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 100%|██████████| 1035/1035 [00:01<00:00, 589.32it/s]
# All distance statistics:
# count    1220.000000
# mean        0.000522
# std         0.000343
# min         0.000080
# 25%         0.000319
# 50%         0.000433
# 75%         0.000622
# max         0.004018
# dtype: float64
# Your merging_threshold is:  0.0003
# Merge prohibit times by merging_dynamic_constraint: 240
# merging round:  6 current number of segments:  619
#   4%|▍         | 39/1035 [00:00<00:02, 381.00it/s]/home/mlqin/anaconda3/envs/HFT/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/mlqin/anaconda3/envs/HFT/lib/python3.8/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 100%|██████████| 1035/1035 [00:02<00:00, 511.76it/s]
# All distance statistics:
# count    1214.000000
# mean        0.000523
# std         0.000343
# min         0.000080
# 25%         0.000320
# 50%         0.000432
# 75%         0.000622
# max         0.004018
# dtype: float64
# Your merging_threshold is:  0.0003
# Merge prohibit times by merging_dynamic_constraint: 238
# merging round:  7 current number of segments:  618
#   4%|▎         | 37/1035 [00:00<00:02, 362.05it/s]/home/mlqin/anaconda3/envs/HFT/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/mlqin/anaconda3/envs/HFT/lib/python3.8/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 100%|██████████| 1035/1035 [00:02<00:00, 488.98it/s]
# All distance statistics:
# count    1212.000000
# mean        0.000524
# std         0.000343
# min         0.000080
# 25%         0.000321
# 50%         0.000434
# 75%         0.000622
# max         0.004018
# dtype: float64
# Your merging_threshold is:  0.0003
# Merge prohibit times by merging_dynamic_constraint: 236
# merging round:  8 current number of segments:  617
#   3%|▎         | 32/1035 [00:00<00:03, 308.37it/s]/home/mlqin/anaconda3/envs/HFT/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/mlqin/anaconda3/envs/HFT/lib/python3.8/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 100%|██████████| 1035/1035 [00:02<00:00, 453.34it/s]
# All distance statistics:
# count    1210.000000
# mean        0.000524
# std         0.000343
# min         0.000081
# 25%         0.000320
# 50%         0.000435
# 75%         0.000622
# max         0.004018
# dtype: float64
# Your merging_threshold is:  0.0003
# Merge prohibit times by merging_dynamic_constraint: 234
# merging round:  9 current number of segments:  616
#   3%|▎         | 32/1035 [00:00<00:03, 312.38it/s]/home/mlqin/anaconda3/envs/HFT/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/mlqin/anaconda3/envs/HFT/lib/python3.8/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 100%|██████████| 1035/1035 [00:02<00:00, 421.10it/s]
# All distance statistics:
# count    1208.000000
# mean        0.000525
# std         0.000343
# min         0.000081
# 25%         0.000321
# 50%         0.000434
# 75%         0.000622
# max         0.004018
# dtype: float64
# Your merging_threshold is:  0.0003
# Merge prohibit times by merging_dynamic_constraint: 231
# merging round:  10 current number of segments:  612
#   3%|▎         | 32/1035 [00:00<00:03, 303.01it/s]/home/mlqin/anaconda3/envs/HFT/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/mlqin/anaconda3/envs/HFT/lib/python3.8/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 100%|██████████| 1035/1035 [00:02<00:00, 391.13it/s]
# All distance statistics:
# count    1200.000000
# mean        0.000526
# std         0.000344
# min         0.000081
# 25%         0.000322
# 50%         0.000435
# 75%         0.000622
# max         0.004018
# dtype: float64
# Your merging_threshold is:  0.0003
# Merge prohibit times by merging_dynamic_constraint: 230
# merging_round in total: 10, number of segments: 613
# You may want to tune the merging_threshold and merging_dynamic_constraint to get a better result.
# finish fitting
# finish labeling
# labeling done
# start save whole file !!!!!!!!!!!!!!!!!!!!!!!!
# saving done !!!!!!!!!!!!!!!!!!!!!!!!
# {'timestamp': Timestamp('2023-05-06 14:48:21'), 'action': 'buy', 'order': [{'price': 28667.82, 'amount': 0.0021}, {'price': 28668.23, 'amount': 0.00209}, {'price': 28668.59, 'amount': 0.002}, {'price': 28668.71, 'amount': 0.003810000000000001}], 'position': 0.01}
# add buy/opening record 2023-05-06 14:48:21
# {'timestamp': Timestamp('2023-05-06 15:35:37'), 'action': 'sell', 'order': [{'price': 28596.89, 'amount': 0.01}], 'position': 0.0}
# add sell/closing record 2023-05-06 15:35:37
# {'timestamp': Timestamp('2023-05-06 15:39:00'), 'action': 'buy', 'order': [{'price': 28631.9, 'amount': 0.01}], 'position': 0.01}
# add buy/opening record 2023-05-06 15:39:00
# {'timestamp': Timestamp('2023-05-06 17:27:07'), 'action': 'sell', 'order': [{'price': 28816.49, 'amount': 0.0025}], 'position': 0.0075}
# {'timestamp': Timestamp('2023-05-06 17:27:11'), 'action': 'buy', 'order': [{'price': 28814.55, 'amount': 0.0025}], 'position': 0.01}
# {'timestamp': Timestamp('2023-05-06 18:18:11'), 'action': 'sell', 'order': [{'price': 28954.01, 'amount': 0.01}], 'position': 0.0}
# add sell/closing record 2023-05-06 18:18:11
# {'timestamp': Timestamp('2023-05-06 18:18:33'), 'action': 'buy', 'order': [{'price': 28929.0, 'amount': 0.01}], 'position': 0.01}
# add buy/opening record 2023-05-06 18:18:33
# {'timestamp': Timestamp('2023-05-06 18:44:25'), 'action': 'sell', 'order': [{'price': 28965.38, 'amount': 0.0025}], 'position': 0.0075}
# {'timestamp': Timestamp('2023-05-06 18:44:26'), 'action': 'sell', 'order': [{'price': 28962.9, 'amount': 0.0075}], 'position': 0.0}
# add sell/closing record 2023-05-06 18:44:26
# {'timestamp': Timestamp('2023-05-06 18:49:28'), 'action': 'buy', 'order': [{'price': 28972.05, 'amount': 0.01}], 'position': 0.01}
# add buy/opening record 2023-05-06 18:49:28
# {'timestamp': Timestamp('2023-05-06 21:58:30'), 'action': 'sell', 'order': [{'price': 28854.9, 'amount': 0.0075}], 'position': 0.0025}
# {'timestamp': Timestamp('2023-05-06 21:58:45'), 'action': 'sell', 'order': [{'price': 28848.18, 'amount': 0.0025}], 'position': 0.0}
# add sell/closing record 2023-05-06 21:58:45
# {'timestamp': Timestamp('2023-05-06 23:08:15'), 'action': 'buy', 'order': [{'price': 28907.18, 'amount': 0.00038}, {'price': 28907.92, 'amount': 0.00962}], 'position': 0.01}
# add buy/opening record 2023-05-06 23:08:15
# {'timestamp': Timestamp('2023-05-07 00:54:06'), 'action': 'sell', 'order': [{'price': 28970.21, 'amount': 0.0075}], 'position': 0.0025}
# {'timestamp': Timestamp('2023-05-07 00:54:10'), 'action': 'sell', 'order': [{'price': 28976.65, 'amount': 0.0025}], 'position': 0.0}
# add sell/closing record 2023-05-07 00:54:10
# {'timestamp': Timestamp('2023-05-07 01:19:10'), 'action': 'buy', 'order': [{'price': 28971.47, 'amount': 0.01}], 'position': 0.01}
# add buy/opening record 2023-05-07 01:19:10
# {'timestamp': Timestamp('2023-05-07 01:27:37'), 'action': 'sell', 'order': [{'price': 29138.08, 'amount': 0.0075}], 'position': 0.0025}
# {'timestamp': Timestamp('2023-05-07 01:27:39'), 'action': 'sell', 'order': [{'price': 29127.63, 'amount': 0.00045}, {'price': 29127.62, 'amount': 0.00205}], 'position': 0.0}
# add sell/closing record 2023-05-07 01:27:39
# {'timestamp': Timestamp('2023-05-07 01:28:26'), 'action': 'buy', 'order': [{'price': 29136.36, 'amount': 0.00403}, {'price': 29136.37, 'amount': 0.0059700000000000005}], 'position': 0.01}
# add buy/opening record 2023-05-07 01:28:26
# {'timestamp': Timestamp('2023-05-07 05:32:26'), 'action': 'sell', 'order': [{'price': 28906.81, 'amount': 0.00068}, {'price': 28906.8, 'amount': 0.00682}], 'position': 0.0025}
# {'timestamp': Timestamp('2023-05-07 05:33:08'), 'action': 'sell', 'order': [{'price': 28913.43, 'amount': 0.0025}], 'position': 0.0}
# add sell/closing record 2023-05-07 05:33:08
# {'timestamp': Timestamp('2023-05-07 11:38:08'), 'action': 'buy', 'order': [{'price': 28950.99, 'amount': 0.01}], 'position': 0.01}
# add buy/opening record 2023-05-07 11:38:08
# {'timestamp': Timestamp('2023-05-07 14:34:30'), 'action': 'sell', 'order': [{'price': 29045.07, 'amount': 0.01}], 'position': 0.0}
# add sell/closing record 2023-05-07 14:34:30
# {'timestamp': Timestamp('2023-05-07 14:34:31'), 'action': 'buy', 'order': [{'price': 29040.75, 'amount': 0.00434}, {'price': 29049.15, 'amount': 0.00066}], 'position': 0.005}
# add buy/opening record 2023-05-07 14:34:31
# {'timestamp': Timestamp('2023-05-07 14:34:32'), 'action': 'sell', 'order': [{'price': 29033.77, 'amount': 0.005}], 'position': 0.0}
# add sell/closing record 2023-05-07 14:34:32
# {'timestamp': Timestamp('2023-05-07 14:35:04'), 'action': 'buy', 'order': [{'price': 29057.14, 'amount': 0.0075}], 'position': 0.0075}
# add buy/opening record 2023-05-07 14:35:04
# {'timestamp': Timestamp('2023-05-07 14:35:08'), 'action': 'buy', 'order': [{'price': 29049.11, 'amount': 0.0025}], 'position': 0.01}
# {'timestamp': Timestamp('2023-05-07 14:49:19'), 'action': 'sell', 'order': [{'price': 29053.69, 'amount': 0.002}, {'price': 29050.98, 'amount': 0.00164}, {'price': 29050.64, 'amount': 0.0038599999999999997}], 'position': 0.0025}
# {'timestamp': Timestamp('2023-05-07 14:49:24'), 'action': 'sell', 'order': [{'price': 29053.88, 'amount': 0.0025}], 'position': 0.0}
# add sell/closing record 2023-05-07 14:49:24
# {'timestamp': Timestamp('2023-05-07 14:50:20'), 'action': 'buy', 'order': [{'price': 29090.45, 'amount': 0.01}], 'position': 0.01}
# add buy/opening record 2023-05-07 14:50:20
# {'timestamp': Timestamp('2023-05-07 15:09:42'), 'action': 'sell', 'order': [{'price': 29051.9, 'amount': 0.00035}, {'price': 29046.71, 'amount': 0.00965}], 'position': 0.0}
# add sell/closing record 2023-05-07 15:09:42
# {'timestamp': Timestamp('2023-05-07 15:51:11'), 'action': 'buy', 'order': [{'price': 29009.61, 'amount': 3e-05}, {'price': 29009.68, 'amount': 0.00111}, {'price': 29009.95, 'amount': 0.002}, {'price': 29009.96, 'amount': 0.00686}], 'position': 0.01}
# add buy/opening record 2023-05-07 15:51:11
# {'timestamp': numpy.datetime64('2023-05-07T18:22:52.000000000'), 'action': 'sell', 'order': [{'price': 28934.0, 'amount': 0.00156}, {'price': 28933.28, 'amount': 0.0008}, {'price': 28933.0, 'amount': 0.0005}, {'price': 28932.25, 'amount': 0.00044}, {'price': 28932.23, 'amount': 0.0066999999999999985}], 'position': 0}
# add sell/closing record 2023-05-07T18:22:52.000000000
#
# [Timestamp('2023-05-06 14:48:21'), Timestamp('2023-05-06 15:39:00'), Timestamp('2023-05-06 18:18:33'), Timestamp('2023-05-06 18:49:28'), Timestamp('2023-05-06 23:08:15'), Timestamp('2023-05-07 01:19:10'), Timestamp('2023-05-07 01:28:26'), Timestamp('2023-05-07 11:38:08'), Timestamp('2023-05-07 14:34:31'), Timestamp('2023-05-07 14:35:04'), Timestamp('2023-05-07 14:50:20'), Timestamp('2023-05-07 15:51:11')]
# [Timestamp('2023-05-06 15:35:37'), Timestamp('2023-05-06 18:18:11'), Timestamp('2023-05-06 18:44:26'), Timestamp('2023-05-06 21:58:45'), Timestamp('2023-05-07 00:54:10'), Timestamp('2023-05-07 01:27:39'), Timestamp('2023-05-07 05:33:08'), Timestamp('2023-05-07 14:34:30'), Timestamp('2023-05-07 14:34:32'), Timestamp('2023-05-07 14:49:24'), Timestamp('2023-05-07 15:09:42'), numpy.datetime64('2023-05-07T18:22:52.000000000')]
# 12
# 12
# opening_strategy_timestamp_list [Timestamp('2023-05-06 14:48:21'), Timestamp('2023-05-06 15:39:00'), Timestamp('2023-05-06 18:18:33')]
# closing_strategy_timestamp_list [Timestamp('2023-05-06 15:35:37'), Timestamp('2023-05-06 18:18:11'), Timestamp('2023-05-06 18:44:26')]
# in the 0th segment, the total return rate is 0.008551942544725355, the max drawdown is 0.007674075087742459, the calmar ratio is 1.1143939102687546, the mean return rate, mean duration, mean max drawdown, win rate is as follow
# opening_strategy_timestamp_list [Timestamp('2023-05-06 18:49:28'), Timestamp('2023-05-06 23:08:15')]
# closing_strategy_timestamp_list [Timestamp('2023-05-06 21:58:45'), Timestamp('2023-05-07 00:54:10')]
# in the 1th segment, the total return rate is -0.0009474973293225331, the max drawdown is 0.005621877513231536, the calmar ratio is -0.16853752631438923, the mean return rate, mean duration, mean max drawdown, win rate is as follow
# opening_strategy_timestamp_list [Timestamp('2023-05-07 01:19:10'), Timestamp('2023-05-07 01:28:26')]
# closing_strategy_timestamp_list [Timestamp('2023-05-07 01:27:39'), Timestamp('2023-05-07 05:33:08')]
# in the 2th segment, the total return rate is -0.0011030220420295, the max drawdown is 0.006530318742621978, the calmar ratio is -0.16890784133250858, the mean return rate, mean duration, mean max drawdown, win rate is as follow
# opening_strategy_timestamp_list [Timestamp('2023-05-07 11:38:08'), Timestamp('2023-05-07 14:34:31')]
# closing_strategy_timestamp_list [Timestamp('2023-05-07 14:34:30'), Timestamp('2023-05-07 14:34:32')]
# in the 3th segment, the total return rate is 0.0015549658232758556, the max drawdown is 0.0019282362856155595, the calmar ratio is 0.8064187127250626, the mean return rate, mean duration, mean max drawdown, win rate is as follow
# opening_strategy_timestamp_list [Timestamp('2023-05-07 14:35:04'), Timestamp('2023-05-07 14:50:20'), Timestamp('2023-05-07 15:51:11')]
# closing_strategy_timestamp_list [Timestamp('2023-05-07 14:49:24'), Timestamp('2023-05-07 15:09:42'), numpy.datetime64('2023-05-07T18:22:52.000000000')]
# in the 4th segment, the total return rate is -0.002131662280321911, the max drawdown is 0.004260465021394952, the calmar ratio is -0.50033559003941, the mean return rate, mean duration, mean max drawdown, win rate is as follow

# %%
open = [pd.Timestamp('2023-05-06 14:48:21'), pd.Timestamp('2023-05-06 15:39:00'), pd.Timestamp('2023-05-06 18:18:33'), pd.Timestamp('2023-05-06 18:49:28'), pd.Timestamp('2023-05-06 23:08:15'), pd.Timestamp('2023-05-07 01:19:10'), pd.Timestamp('2023-05-07 01:28:26'), pd.Timestamp('2023-05-07 11:38:08'), pd.Timestamp('2023-05-07 14:34:31'), pd.Timestamp('2023-05-07 14:35:04'), pd.Timestamp('2023-05-07 14:50:20'), pd.Timestamp('2023-05-07 15:51:11'), pd.Timestamp('2023-05-08 00:12:12'), pd.Timestamp('2023-05-08 01:31:04'), pd.Timestamp('2023-05-08 01:41:33'), pd.Timestamp('2023-05-08 01:43:28'), pd.Timestamp('2023-05-08 01:43:55'), pd.Timestamp('2023-05-08 01:44:32'), pd.Timestamp('2023-05-08 01:47:08'), pd.Timestamp('2023-05-08 03:44:42'), pd.Timestamp('2023-05-08 14:49:17'), pd.Timestamp('2023-05-08 18:00:01'), pd.Timestamp('2023-05-08 18:00:57'), pd.Timestamp('2023-05-08 18:19:05'), pd.Timestamp('2023-05-08 18:54:10'), pd.Timestamp('2023-05-08 21:24:19'), pd.Timestamp('2023-05-08 23:52:19'), pd.Timestamp('2023-05-09 05:44:05'), pd.Timestamp('2023-05-09 10:18:10'), pd.Timestamp('2023-05-09 11:52:00'), pd.Timestamp('2023-05-09 12:16:13'), pd.Timestamp('2023-05-09 14:41:37'), pd.Timestamp('2023-05-09 16:37:15'), pd.Timestamp('2023-05-09 16:46:38'), pd.Timestamp('2023-05-09 17:02:25'), pd.Timestamp('2023-05-10 08:12:24'), pd.Timestamp('2023-05-10 12:32:11'), pd.Timestamp('2023-05-10 12:56:45'), pd.Timestamp('2023-05-10 17:15:39'), pd.Timestamp('2023-05-10 17:17:00'), pd.Timestamp('2023-05-10 17:17:53'), pd.Timestamp('2023-05-10 17:21:17'), pd.Timestamp('2023-05-10 17:39:33'), pd.Timestamp('2023-05-10 17:48:07'), pd.Timestamp('2023-05-10 19:24:09'), pd.Timestamp('2023-05-10 20:08:02'), pd.Timestamp('2023-05-10 21:23:48'), pd.Timestamp('2023-05-10 21:29:10'), pd.Timestamp('2023-05-10 22:49:58'), pd.Timestamp('2023-05-10 23:51:51'), pd.Timestamp('2023-05-11 10:21:15'), pd.Timestamp('2023-05-11 12:49:17'), pd.Timestamp('2023-05-11 14:12:02'), pd.Timestamp('2023-05-11 19:57:45'), pd.Timestamp('2023-05-11 20:46:24'), pd.Timestamp('2023-05-11 20:53:46'), pd.Timestamp('2023-05-12 04:04:25'), pd.Timestamp('2023-05-12 05:57:01'), pd.Timestamp('2023-05-12 08:38:33'), pd.Timestamp('2023-05-12 09:50:02'), pd.Timestamp('2023-05-12 12:26:04'), pd.Timestamp('2023-05-12 19:25:57'), pd.Timestamp('2023-05-12 19:33:06'), pd.Timestamp('2023-05-12 19:50:30'), pd.Timestamp('2023-05-12 19:56:27'), pd.Timestamp('2023-05-12 21:01:03'), pd.Timestamp('2023-05-12 21:13:19'), pd.Timestamp('2023-05-12 22:14:22'), pd.Timestamp('2023-05-13 01:08:49'), pd.Timestamp('2023-05-13 01:19:00'), pd.Timestamp('2023-05-13 18:49:03'), pd.Timestamp('2023-05-13 19:13:10'), pd.Timestamp('2023-05-13 21:28:05'), pd.Timestamp('2023-05-14 01:32:29'), pd.Timestamp('2023-05-14 02:04:01'), pd.Timestamp('2023-05-14 14:44:25'), pd.Timestamp('2023-05-14 15:18:16'), pd.Timestamp('2023-05-14 17:27:48'), pd.Timestamp('2023-05-15 05:01:32'), pd.Timestamp('2023-05-15 05:46:02'), pd.Timestamp('2023-05-15 06:16:02'), pd.Timestamp('2023-05-15 14:54:48'), pd.Timestamp('2023-05-15 17:57:30')]

# %%
close = [pd.Timestamp('2023-05-06 15:35:37'), pd.Timestamp('2023-05-06 18:18:11'), pd.Timestamp('2023-05-06 18:44:26'), pd.Timestamp('2023-05-06 21:58:45'), pd.Timestamp('2023-05-07 00:54:10'), pd.Timestamp('2023-05-07 01:27:39'), pd.Timestamp('2023-05-07 05:33:08'), pd.Timestamp('2023-05-07 14:34:30'), pd.Timestamp('2023-05-07 14:34:32'), pd.Timestamp('2023-05-07 14:49:24'), pd.Timestamp('2023-05-07 15:09:42'), pd.Timestamp('2023-05-07 20:11:01'), pd.Timestamp('2023-05-08 00:42:15'), pd.Timestamp('2023-05-08 01:31:05'), pd.Timestamp('2023-05-08 01:43:22'), pd.Timestamp('2023-05-08 01:43:45'), pd.Timestamp('2023-05-08 01:44:29'), pd.Timestamp('2023-05-08 01:47:03'), pd.Timestamp('2023-05-08 02:16:41'), pd.Timestamp('2023-05-08 13:38:53'), pd.Timestamp('2023-05-08 17:55:46'), pd.Timestamp('2023-05-08 18:00:55'), pd.Timestamp('2023-05-08 18:05:02'), pd.Timestamp('2023-05-08 18:54:05'), pd.Timestamp('2023-05-08 20:41:13'), pd.Timestamp('2023-05-08 22:47:50'), pd.Timestamp('2023-05-09 03:01:01'), pd.Timestamp('2023-05-09 06:47:37'), pd.Timestamp('2023-05-09 11:45:16'), pd.Timestamp('2023-05-09 12:15:07'), pd.Timestamp('2023-05-09 13:07:45'), pd.Timestamp('2023-05-09 14:48:33'), pd.Timestamp('2023-05-09 16:39:02'), pd.Timestamp('2023-05-09 17:02:11'), pd.Timestamp('2023-05-10 00:21:34'), pd.Timestamp('2023-05-10 11:59:19'), pd.Timestamp('2023-05-10 12:56:42'), pd.Timestamp('2023-05-10 15:39:13'), pd.Timestamp('2023-05-10 17:15:48'), pd.Timestamp('2023-05-10 17:17:02'), pd.Timestamp('2023-05-10 17:21:16'), pd.Timestamp('2023-05-10 17:39:16'), pd.Timestamp('2023-05-10 17:48:04'), pd.Timestamp('2023-05-10 19:12:44'), pd.Timestamp('2023-05-10 19:54:06'), pd.Timestamp('2023-05-10 20:40:37'), pd.Timestamp('2023-05-10 21:23:51'), pd.Timestamp('2023-05-10 22:05:48'), pd.Timestamp('2023-05-10 22:59:03'), pd.Timestamp('2023-05-11 01:19:13'), pd.Timestamp('2023-05-11 12:31:01'), pd.Timestamp('2023-05-11 14:05:21'), pd.Timestamp('2023-05-11 18:49:17'), pd.Timestamp('2023-05-11 20:40:01'), pd.Timestamp('2023-05-11 20:47:59'), pd.Timestamp('2023-05-12 00:45:52'), pd.Timestamp('2023-05-12 05:55:01'), pd.Timestamp('2023-05-12 07:18:15'), pd.Timestamp('2023-05-12 09:09:04'), pd.Timestamp('2023-05-12 12:16:01'), pd.Timestamp('2023-05-12 19:25:56'), pd.Timestamp('2023-05-12 19:25:58'), pd.Timestamp('2023-05-12 19:49:59'), pd.Timestamp('2023-05-12 19:56:24'), pd.Timestamp('2023-05-12 20:57:03'), pd.Timestamp('2023-05-12 21:10:21'), pd.Timestamp('2023-05-12 22:12:09'), pd.Timestamp('2023-05-13 01:08:12'), pd.Timestamp('2023-05-13 01:18:26'), pd.Timestamp('2023-05-13 05:21:38'), pd.Timestamp('2023-05-13 18:49:04'), pd.Timestamp('2023-05-13 19:24:00'), pd.Timestamp('2023-05-13 22:11:50'), pd.Timestamp('2023-05-14 01:40:07'), pd.Timestamp('2023-05-14 02:05:27'), pd.Timestamp('2023-05-14 15:16:44'), pd.Timestamp('2023-05-14 16:11:21'), pd.Timestamp('2023-05-14 21:16:04'), pd.Timestamp('2023-05-15 01:54:37'), pd.Timestamp('2023-05-15 05:01:34'), pd.Timestamp('2023-05-15 05:55:51'), pd.Timestamp('2023-05-15 14:53:45'), pd.Timestamp('2023-05-15 17:13:34'), pd.Timestamp('2023-05-15 19:45:55')]

# %%
for i in range(83):
  if open[i]<close[i] and open[i+1]>close[i]:
    continue
  else:
    print(open[i])
    print(open[i+1])
    print(close[i])
    print(i)
    print()
# Out:
# 2023-05-15 05:01:32
# 2023-05-15 05:46:02
# 2023-05-15 01:54:37
# 78
#
# 2023-05-15 05:46:02
# 2023-05-15 06:16:02
# 2023-05-15 05:01:34
# 79
#
# 2023-05-15 06:16:02
# 2023-05-15 14:54:48
# 2023-05-15 05:55:51
# 80
#
# 2023-05-15 14:54:48
# 2023-05-15 17:57:30
# 2023-05-15 14:53:45
# 81
#
# 2023-05-15 17:57:30
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/mlqin/lxy/Evaluation/comprehensive_evaluation/analyzer0913.ipynb Cell 15 line <cell line: 1>()
#       <a href='vscode-notebook-cell://ssh-remote%2B155.69.148.74/home/mlqin/lxy/Evaluation/comprehensive_evaluation/analyzer0913.ipynb#X64sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> else:
#       <a href='vscode-notebook-cell://ssh-remote%2B155.69.148.74/home/mlqin/lxy/Evaluation/comprehensive_evaluation/analyzer0913.ipynb#X64sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>   print(open[i])
# ----> <a href='vscode-notebook-cell://ssh-remote%2B155.69.148.74/home/mlqin/lxy/Evaluation/comprehensive_evaluation/analyzer0913.ipynb#X64sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>   print(open[i+1])
#       <a href='vscode-notebook-cell://ssh-remote%2B155.69.148.74/home/mlqin/lxy/Evaluation/comprehensive_evaluation/analyzer0913.ipynb#X64sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>   print(close[i])
#       <a href='vscode-notebook-cell://ssh-remote%2B155.69.148.74/home/mlqin/lxy/Evaluation/comprehensive_evaluation/analyzer0913.ipynb#X64sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>   print(i)
#
# IndexError: list index out of range

# %%
opening_count_perc = [
    [float(format(x / sum(opening_count), ".2f")) for x in opening_count]
    for opening_count in opening_count_seg
]
closing_count_perc = [
    [float(format(x / sum(closing_count), ".2f")) for x in closing_count]
    for closing_count in closing_count_seg
]
opening_amount_perc = [
    [float(format(x / sum(opening_amount), ".2f")) for x in opening_amount]
    for opening_amount in opening_amount_seg
]
closing_amount_perc = [
    [float(format(x / sum(closing_amount), ".2f")) for x in closing_amount]
    for closing_amount in closing_amount_seg
]

color_list = ["#8ECFC9", "#FFBE7A", "#FA7F6F", "#BEB8DC", "#2878B5"]
x_label = ["phase1", "phase2", "phase3", "phase4", "phase5"]
y_label = ["Bull", "Rally", "Sideways", "Pullback", "Bear"]
y_label.reverse()

x_ax = np.array(range(len(x_label))) * 4

fig = plt.figure(figsize=(24, 24))
# plt.suptitle('Opening/Closing counts/amounts along different time with diff market type')

patches = [
    mpatches.Patch(color=color_list[i], label="{:s}".format(y_label[i]))
    for i in range(len(color_list))
]

ax = plt.gca()
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width, box.height * 0.75])
fig.legend(
    handles=patches,
    loc="upper center",
    bbox_to_anchor=(0.5, 0.93),
    ncol=5,
    fontsize="large",
)

plt.subplot(221)
plt.xlabel("Time", fontsize="xx-large")
plt.ylabel("Count", fontsize="xx-large")
plt.title("Opening count")
for i in range(5):
    plt.bar(
        [m + i * 0.75 for m in x_ax],
        [count[i] for count in opening_count_seg],
        label=y_label[i],
        width=0.75,
        color=color_list[i],
    )
plt.xticks([i + 1 for i in x_ax], x_label, fontsize="x-large")
for i in range(len(opening_count_seg)):
    plotdata = [count[i] for count in opening_count_seg]
    for x, y in enumerate(plotdata):
        plt.text(
            x * 4 + i * 0.75,
            y + 0.1,
            format(opening_count_perc[x][i] * 100, ".0f") + "%",
            ha="center",
            fontsize=9,
        )

plt.subplot(222)
plt.xlabel("Time", fontsize="xx-large")
plt.ylabel("Count", fontsize="xx-large")
plt.title("Closing count")
for i in range(5):
    plt.bar(
        [m + i * 0.75 for m in x_ax],
        [count[i] for count in closing_count_seg],
        label=y_label[i],
        width=0.75,
        color=color_list[i],
    )
plt.xticks([i + 1.5 for i in x_ax], x_label, fontsize="x-large")
for i in range(len(closing_count_seg)):
    plotdata = [count[i] for count in closing_count_seg]
    for x, y in enumerate(plotdata):
        plt.text(
            x * 4 + i * 0.75,
            y + 0.1,
            format(closing_count_perc[x][i] * 100, ".0f") + "%",
            ha="center",
            fontsize=9,
        )

plt.subplot(223)
plt.xlabel("Time", fontsize="xx-large")
plt.ylabel("Volume", fontsize="xx-large")
plt.title("Opening volume")
for i in range(5):
    plt.bar(
        [m + i * 0.75 for m in x_ax],
        [count[i] for count in opening_amount_seg],
        label=y_label[i],
        width=0.75,
        color=color_list[i],
    )
plt.xticks([i + 1.5 for i in x_ax], x_label, fontsize="x-large")
for i in range(len(opening_amount_seg)):
    plotdata = [count[i] for count in opening_amount_seg]
    for x, y in enumerate(plotdata):
        plt.text(
            x * 4 + i * 0.75,
            y + 0.003,
            format(opening_amount_perc[x][i] * 100, ".0f") + "%",
            ha="center",
            fontsize=9,
        )

plt.subplot(224)
plt.xlabel("Time", fontsize="xx-large")
plt.ylabel("Volume", fontsize="xx-large")
plt.title("Closing volume")
for i in range(5):
    plt.bar(
        [m + i * 0.75 for m in x_ax],
        [count[i] for count in closing_amount_seg],
        label=y_label[i],
        width=0.75,
        color=color_list[i],
    )
plt.xticks([i + 1.5 for i in x_ax], x_label, fontsize="x-large")
for i in range(len(closing_amount_seg)):
    plotdata = [count[i] for count in closing_amount_seg]
    for x, y in enumerate(plotdata):
        plt.text(
            x * 4 + i * 0.75,
            y + 0.003,
            format(closing_amount_perc[x][i] * 100, ".0f") + "%",
            ha="center",
            fontsize=9,
        )

img_path = path + "/time_dynamics_proportion.pdf"
plt.savefig(img_path, bbox_inches="tight")
# plt.show()
# Out:
# /tmp/ipykernel_4161772/1704861975.py:44: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(221)
